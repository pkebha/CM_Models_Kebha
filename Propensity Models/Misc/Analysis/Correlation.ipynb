# %%
import pandas as pd

# %%
data_set=pd.read_csv('MV_Analysi_20221118-1668769996287.csv')
data_set
# Out:
#         appops_status_code  p_credit_score  p_customer_type  income  \
# 0                      990             700                1   80000
# 1                      990             700                1   80000
# 2                      990             700                1   80000
# 3                      990             700                1   80000
# 4                      990             700                1   80000
# ...                    ...             ...              ...     ...
# 145067                 380             775                1   15000
# 145068                 380             775                1   20000
# 145069                 380             775                1   20000
# 145070                 380             775                1   50000
# 145071                 380             775                1   50000
#
#            employment  final_annual_turnover
# 0                 NaN               100000.0
# 1                 NaN               100000.0
# ...

# %%
data_set.columns
# Out:
# Index(['appops_status_code', 'p_credit_score', 'p_customer_type', 'income',
#        'employment', 'final_annual_turnover'],
#       dtype='object')

# %%
dataset=data_set.drop(['lead_id',  'customer_profile_id', 'user_id',
       'report_source', 'report_id', 'report_date',
       'filename_prefix', 'status', 'pan_no', 'passport_no',
       'driving_license_no', 'voter_id_no', 'ration_card_no', 'uid_no',
       'national_card_no', 'photo_credit_card_no', 'other_id_no',
       'account_type', 'reported_on', 'p_occupation', 'p_equifax_income',
       'frequency', 'income_indicator', 'total_accounts',
       'negative_status_accounts', 'positive_status_accounts', 'open_accounts',
       'closed_accounts', 'max_dpd', 'credit_utilization', 'enquiries_made',
       'seasoning', 'portfolio_mix_secured', 'portfolio_mix_unsecured',
       'related_accounts', 'annual_income', 'calculated_emi',
       'ability_to_borrow_cc', 'ability_to_borrow_hl', 'ability_to_borrow_pl',
       'ability_to_borrow_al', 'minor_issues', 'ontime_payment_percentage',
       'no_of_delayed_payments', 'no_of_delayed_payments_on_active_accounts',
       'no_of_active_accounts', 'created_on', 'modified_on', 'modified_by',
       'modified_ts', 'existing_foir', 'credit_utilization_avg', 'is_active',
       'is_saleable', 'monthly_income', 'annual_turnover', 'employment_type', 'nature_of_employment',
       'annualturnover'], axis=1)
dataset
# Out:
#         appops_status_code  p_credit_score  p_customer_type   income  \
# 0                      990             750                1  60000.0
# 1                      990             750                1  60000.0
# 2                      990             775                1  60000.0
# 3                      990             700                1  80000.0
# 4                      990             700                1  80000.0
# ...                    ...             ...              ...      ...
# 530225                 380             525                2      NaN
# 530226                 380             575                1      NaN
# 530227                 380             750                1      NaN
# 530228                 380             575                1      NaN
# 530229                 380             575                1      NaN
#
#        employment final_annual_turnover
# 0             NaN                   NaN
# 1             NaN                   NaN
# ...

# %%
# data_set['age'] = data_set['age'].fillna(0)
# data_set['city'] = data_set['city'].fillna('NA')
# data_set['monthly_income'] = data_set['monthly_income'].fillna(0)
# data_set['salary_receive_type'] = data_set['salary_receive_type'].fillna('NA')
# data_set['pat'] = data_set['pat'].fillna(0)
# data_set['nth'] = data_set['nth'].fillna(0)
# data_set['employment_type'] = data_set['employment_type'].fillna('NA')
# data_set['no_of_delayed_payments'] = data_set['no_of_delayed_payments'].fillna(0)
# data_set['no_of_delayed_payments_on_active_accounts'] = data_set['no_of_delayed_payments_on_active_accounts'].fillna(0)
# data_set['p_credit_score'] = data_set['p_credit_score'].fillna(0)
# data_set['converted'] = data_set['converted'].fillna(0)
# data_set['monthly_income'] = data_set['monthly_income'].fillna(0)
# data_set['annual_turnover'] = data_set['annual_turnover'].fillna(0)
dataset['income'] = dataset['income'].fillna(0)
dataset['employment'] = dataset['employment'].fillna('Empty')
dataset['final_annual_turnover'] = dataset['final_annual_turnover'].fillna(0)
# data_set=data_set.dropna()

# %%
dataset.corr()
# Out:
#                     appops_status_code  p_credit_score  p_customer_type
# appops_status_code            1.000000        0.046187        -0.052658
# p_credit_score                0.046187        1.000000        -0.929720
# p_customer_type              -0.052658       -0.929720         1.000000

# %%
import seaborn as sns
 
# checking correlation using heatmap
 
#plotting the heatmap for correlation
ax = sns.heatmap(dataset.corr(), annot=True, fmt=".1f")

# %%
data_set.corr()
# Out:
#                                             lead_id   user_id  \
# lead_id                                    1.000000  0.222986
# user_id                                    0.222986  1.000000
# appops_status_code                        -0.083220 -0.068975
# age                                       -0.021050 -0.175836
# monthly_income                             0.004736 -0.000858
# pat                                        0.007811  0.013762
# nth                                        0.002024 -0.000354
# no_of_delayed_payments                    -0.013009 -0.158202
# no_of_delayed_payments_on_active_accounts -0.013013 -0.158151
# p_credit_score                             0.034883  0.084333
# p_customer_type                           -0.028885 -0.081698
# converted                                 -0.083220 -0.068975
#
#                                            appops_status_code       age  \
# lead_id                                             -0.083220 -0.021050
# ...
