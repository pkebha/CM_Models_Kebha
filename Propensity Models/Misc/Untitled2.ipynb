# %%
dictio={'two_wheeler_count': 0.0,
 'citi_neg_flag': 0.0,
 'auto_loan_close_count_last3mnths': 0.0,
 'gold_loan_close_count_last3mnths': 0.0,
 'consumer_loan_close_count_last3mnths': 0.0,
 'housing_loan_close_count_last3mnths': 0.0,
 'credit_card_close_count_last3mnths': 0.0,
 'two_wheeler_close_count_last3mnths': 0.0,
 'secured_close_last3mnths': 0.0,
 'negative_status_close_count_last3mnths': 0.0,
 'joint_account_close_last3mnths': 0.0,
 'max_dpd_on_m9': 0.0,
 'max_dpd_on_m12': 0.0,
 'max_dpd_on_m6': 0.0}

# %%
dictio.keys()
# Out:
# dict_keys(['two_wheeler_count', 'citi_neg_flag', 'auto_loan_close_count_last3mnths', 'gold_loan_close_count_last3mnths', 'consumer_loan_close_count_last3mnths', 'housing_loan_close_count_last3mnths', 'credit_card_close_count_last3mnths', 'two_wheeler_close_count_last3mnths', 'secured_close_last3mnths', 'negative_status_close_count_last3mnths', 'joint_account_close_last3mnths', 'max_dpd_on_m9', 'max_dpd_on_m12', 'max_dpd_on_m6'])

# %%
importance1={'nsaleable': -11.743157429510145,
 'saleable_accounts_count': -11.737094216131755,
 'open_negative_status_count': -2.853287617264186,
 'open_total_ratio': -0.0766592669785909,
 'closed_accounts': -0.06504865656525398,
 'individual_account': -0.05426230172119096,
 'settled_flag': -0.042814675228917076,
 'unique_days_logged_in_flag_Two': -0.03630963195425399,
 'cc_neg_flag': -0.028136266298863864,
 'unique_days_logged_in_flag_One': -0.02563210830635748,
 'positive_response_rate': -0.023748665579205023,
 'score_on_m3': -0.02077002759728138,
 'cl_neg_flag': -0.019268617290161803,
 'individual_close_account_last3mnths': -0.017411156733548754,
 'sms_login_flag_Zero': -0.016330192774127363,
 'secured': -0.014617769377516075,
 'credit_score': -0.01176064516293568,
 'total_balance': -0.009802405131876643,
 'sbi_neg_flag': -0.009069160573155622,
 'housing_loan_count': -0.00905634021024906,
 'hdfc_neg_flag': -0.0077136061387329405,
 'totl_neg_ratio': -0.00520511848266992,
 'score_on_m6': -0.005200033959084285,
 'monthly_income': -0.002541741472769356,
 'unsecured': -0.002444882387803406,
 'icici_neg_flag': -0.000240313372663361,
 'joint_account': -0.0002026899918935192,
 'salary_account_I receive by cash': 0.0,
 'gold_loan_count': 9.709704672574035e-06,
 'score_on_m9': 0.0013577965244286772,
 'unique_days_logged_in_flag_Three': 0.001487259791908005,
 'consumer_loan_count': 0.002008194290431679,
 'neg_acc_on_m3': 0.0023801239306556767,
 'max_score': 0.0025850849103938515,
 'score_on_m12': 0.003726746112986063,
 'total_emi_amount': 0.0062336946859798395,
 'contactability': 0.006511452792813002,
 'email_login_flag_Zero': 0.010873574209784251,
 'pl_neg_flag': 0.011449905087748343,
 'email_login_flag_One': 0.01157765785637415,
 'credit_limit': 0.012897551282331204,
 'ptp_last_three_months_flag': 0.01327580876547778,
 'written_off_accounts': 0.013494451731294018,
 'repayment_tenure': 0.01382187028510299,
 'neg_acc_on_m6': 0.014070162270369953,
 'unsecured_close_last3mnths': 0.014924461950090912,
 'open_accounts': 0.01543548636796104,
 'auto_loan_count': 0.01554157984914541,
 'flows_accounts': 0.017281851259974598,
 'neg_acc_on_m12': 0.02012259782171909,
 'max_dpd_on_m3': 0.021187431436624816,
 'sms_login_flag_One': 0.02484772434920998,
 'age': 0.026234803015511537,
 'neg_acc_on_m9': 0.03147303304640585,
 'personal_loan_count': 0.03200640389227073,
 'closed_accounts_last3mnths': 0.03523946406160848,
 'employment_type_Self Employed': 0.03689604790422616,
 'credit_card_count': 0.037827046187673324,
 'marital_status_Single': 0.04319130681768467,
 'total_amt_sanctioned': 0.04543345715472338,
 'cfp_interest': 0.05054994753282446,
 'settled_accounts': 0.08656855500842033,
 'salary_account_HDFC Bank': 0.2105186805105974,
 'salary_account_andhra bank': 0.2105186805105974,
 'salary_account_JAMMU & KASHMIR': 0.21051868051059772,
 'salary_account_CITI': 0.21051868051059788,
 'salary_account_YESBANK': 0.4210373610211951,
 'salary_account_AXIS': 1.2610277396921963,
 'city_band_Kolkata': 1.4655787852891446,
 'salary_account_ICICI': 2.1031024617345895,
 'salary_account_HDFC': 2.732574159894984,
 'city_band_Pune': 4.2953305113491345,
 'city_band_Mumbai': 4.345855184447436,
 'city_band_Chennai': 4.364784711108315,
 'city_band_Delhi/NCR': 4.497677866578309,
 'city_band_Missing/Others': 4.516713064954397,
 'city_band_Hyderabad': 4.546427741692918,
 'salary_account_SBI': 5.673582656929349,
 'negative_status_flag_One': 5.85165823207545,
 'last_login_vintage_M7toM12': 6.736597776339415,
 'negative_status_flag_Two': 6.79210156369387,
 'negative_status_flag_Three': 7.194977830535409,
 'salary_account_otherBank': 10.08175563100487,
 'last_login_vintage_M3toM6': 11.540221948619276,
 'last_login_vintage_M1toM2': 11.638723821493135,
 'salary_account_Unknown': 12.688668040779461}
importance2={'salary_account_I receive by cash': 0.0,
 'salary_account_JAMMU & KASHMIR': 0.0,
 'salary_account_andhra bank': 0.0,
 'salary_account_HDFC Bank': 4.709212986191835e-05,
 'salary_account_CITI': 6.666247612912708e-05,
 'salary_account_YESBANK': 0.000236747417833296,
 'salary_account_AXIS': 0.0003589988345239229,
 'city_band_Kolkata': 0.00040449440893837566,
 'salary_account_ICICI': 0.0006840444607716017,
 'icici_neg_flag': 0.0006950172066825558,
 'salary_account_HDFC': 0.0007505202103635,
 'city_band_Pune': 0.0009219334860096987,
 'city_band_Chennai': 0.0010645916702851602,
 'negative_status_flag_Three': 0.0012514863988122584,
 'sbi_neg_flag': 0.0012966422229220276,
 'hdfc_neg_flag': 0.0013474387475879632,
 'salary_account_SBI': 0.0015530093115719453,
 'city_band_Mumbai': 0.0016544432931327293,
 'settled_flag': 0.0017902227107902701,
 'cl_neg_flag': 0.0018953206367795252,
 'salary_account_otherBank': 0.0019559178268397587,
 'unique_days_logged_in_flag_Three': 0.0022204966300107707,
 'cc_neg_flag': 0.00243871631974649,
 'unique_days_logged_in_flag_Two': 0.0024491669257152363,
 'email_login_flag_One': 0.002550412230112251,
 'housing_loan_count': 0.0029039905880858335,
 'salary_account_Unknown': 0.0029113326421212698,
 'individual_close_account_last3mnths': 0.0029125834783312247,
 'unique_days_logged_in_flag_One': 0.002925677202315961,
 'max_dpd_on_m3': 0.0029746652925524445,
 'sms_login_flag_One': 0.003378312887011105,
 'closed_accounts_last3mnths': 0.003390115777530106,
 'unsecured_close_last3mnths': 0.003429239009739988,
 'city_band_Hyderabad': 0.0035210801457210487,
 'city_band_Delhi/NCR': 0.0035318840706703085,
 'negative_status_flag_Two': 0.003583107449483776,
 'negative_status_flag_One': 0.004177443014287228,
 'auto_loan_count': 0.004538977020778755,
 'city_band_Missing/Others': 0.005166597425871978,
 'last_login_vintage_M3toM6': 0.005186699317673168,
 'sms_login_flag_Zero': 0.0051967731462036135,
 'joint_account': 0.0059220934552186005,
 'email_login_flag_Zero': 0.006095511289759492,
 'saleable_accounts_count': 0.006458054121359085,
 'last_login_vintage_M1toM2': 0.0073241663871287666,
 'employment_type_Self Employed': 0.007445259519860524,
 'nsaleable': 0.007452114128216457,
 'marital_status_Single': 0.00807171754728114,
 'pl_neg_flag': 0.008104579724544253,
 'open_negative_status_count': 0.008476961201029611,
 'neg_acc_on_m12': 0.008801475041459011,
 'written_off_accounts': 0.008850193488136836,
 'neg_acc_on_m9': 0.010601253961156671,
 'neg_acc_on_m6': 0.011159597371307598,
 'gold_loan_count': 0.011360820189485551,
 'credit_card_count': 0.01267527150477575,
 'score_on_m12': 0.01314135528427186,
 'score_on_m9': 0.014028579854980192,
 'neg_acc_on_m3': 0.015156113050055518,
 'credit_limit': 0.01601234776660336,
 'cfp_interest': 0.017823099991349487,
 'secured': 0.018593296813602535,
 'positive_response_rate': 0.018694020347926957,
 'score_on_m6': 0.018761263805211675,
 'flows_accounts': 0.019064910196427753,
 'consumer_loan_count': 0.019660356749128235,
 'open_accounts': 0.0214377569311115,
 'settled_accounts': 0.022786059318907332,
 'ptp_last_three_months_flag': 0.023091979991331172,
 'score_on_m3': 0.023493841956763073,
 'credit_score': 0.024228549480916142,
 'personal_loan_count': 0.02441947089447205,
 'max_score': 0.025424011615048776,
 'totl_neg_ratio': 0.02562096176759419,
 'closed_accounts': 0.025905751053749093,
 'contactability': 0.02687687464667278,
 'unsecured': 0.027847532592813893,
 'repayment_tenure': 0.03169335388193372,
 'individual_account': 0.03343082844524297,
 'total_amt_sanctioned': 0.03498943433726829,
 'open_total_ratio': 0.0350727700057135,
 'total_balance': 0.036185962901830404,
 'age': 0.03787421478674671,
 'total_emi_amount': 0.03897308647964917,
 'last_login_vintage_M7toM12': 0.04288770758017166,
 'monthly_income': 0.050663584517988705}
total={}

# %%
import numpy as np

# %%
combined=set()
for i in importance1.keys():
    combined.add(i)
for i in importance2.keys():
    combined.add(i)

# %%
for i in combined:
    total[i]=np.abs(importance1[i])+np.abs(importance2[i])

# %%
dict(sorted(total.items(), key=lambda item: item[1]))
# Out:
# {'salary_account_I receive by cash': 0.0,
#  'icici_neg_flag': 0.0009353305793459168,
#  'unique_days_logged_in_flag_Three': 0.0037077564219187755,
#  'joint_account': 0.00612478344711212,
#  'hdfc_neg_flag': 0.009061044886320903,
#  'sbi_neg_flag': 0.010365802796077649,
#  'gold_loan_count': 0.011370529894158125,
#  'housing_loan_count': 0.011960330798334895,
#  'email_login_flag_One': 0.014128070086486401,
#  'score_on_m9': 0.015386376379408869,
#  'score_on_m12': 0.016868101397257924,
#  'email_login_flag_Zero': 0.01696908549954374,
#  'neg_acc_on_m3': 0.017536236980711193,
#  'unsecured_close_last3mnths': 0.0183537009598309,
#  'pl_neg_flag': 0.019554484812292598,
#  'auto_loan_count': 0.020080556869924167,
#  'individual_close_account_last3mnths': 0.02032374021187998,
#  'cl_neg_flag': 0.021163937926941327,
#  'sms_login_flag_Zero': 0.021526965920330977,
#  'consumer_loan_count': 0.021668551039559916,
#  'written_off_accounts': 0.022344645219430852,
# ...

# %%
 'auto_loan_count': 0.020080556869924167,
 'individual_close_account_last3mnths': 0.02032374021187998,
 'cl_neg_flag': 0.021163937926941327,
 'sms_login_flag_Zero': 0.021526965920330977,
 'consumer_loan_count': 0.021668551039559916,
 'written_off_accounts': 0.022344645219430852,
 'score_on_m6': 0.02396129776429596,
 'max_dpd_on_m3': 0.02416209672917726,
 'neg_acc_on_m6': 0.02522975964167755,
 'max_score': 0.028009096525442628,
 'sms_login_flag_One': 0.028226037236221083,
 'unique_days_logged_in_flag_One': 0.028557785508673442,
 'credit_limit': 0.028909899048934564,
 'neg_acc_on_m12': 0.0289240728631781,
 'unsecured': 0.0302924149806173,
 'cc_neg_flag': 0.030574982618610354,
 'totl_neg_ratio': 0.03082608025026411,
 'secured': 0.03321106619111861,
 'contactability': 0.03338832743948578,
 'credit_score': 0.03598919464385182,
 'flows_accounts': 0.03634676145640235,
 'ptp_last_three_months_flag': 0.036367788756808954,
 'open_accounts': 0.03687324329907254,
 'closed_accounts_last3mnths': 0.03862957983913859,
 'unique_days_logged_in_flag_Two': 0.038758798879969227,
 'neg_acc_on_m9': 0.04207428700756252,
 'positive_response_rate': 0.042442685927131976,
 'score_on_m3': 0.044263869554044454,
 'employment_type_Self Employed': 0.044341307424086686,
 'settled_flag': 0.044604897939707344,
 'total_emi_amount': 0.04520678116562901,
 'repayment_tenure': 0.04551522416703671,
 'total_balance': 0.045988368033707046,
