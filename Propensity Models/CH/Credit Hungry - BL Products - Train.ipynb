# %% [markdown]
# # Credit Hungry for BL Products Model

# %%
'''Importing Required Libraries'''
import copy
from collections import OrderedDict
import pandas as pd
import lightgbm as lgb
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.options.display.float_format = '{:.2f}'.format
pd.options.mode.chained_assignment = None  # default='warn'
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import scatter_matrix
from matplotlib import pyplot
from scipy import stats
from scipy.stats import norm, skew
from sklearn.preprocessing import PowerTransformer, QuantileTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import LogisticRegression, SGDClassifier,SGDRegressor
from sklearn.ensemble import RandomForestClassifier,VotingClassifier
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import accuracy_score, roc_curve, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.pipeline import make_pipeline
import joblib
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# %%
'''Importing the data for modelling'''
ch_data = pd.read_csv(r"D:\Dbeaver Out\CH_BL_data_2207_matched_202303211949.csv", na_values=['',' ','NH', 'NA', '[]'], low_memory=False)

# %%
ch_data.drop(['status','report_source', 'report_id', 'report_date', 'filename_prefix', 'pan_no',
        'passport_no', 'driving_license_no', 'voter_id_no', 'ration_card_no',
        'uid_no', 'national_card_no', 'photo_credit_card_no', 'other_id_no',
        'account_type', 'reported_on', 'frequency', 'income_indicator',
        'ability_to_borrow_cc', 'ability_to_borrow_hl', 'ability_to_borrow_pl',
        'ability_to_borrow_al','created_on', 'modified_on', 'modified_by', 'modified_ts','is_active'],axis=1,inplace=True)

# %%
ch_data.annual_income = ch_data.annual_income.apply(lambda x: (x * -1) if x < 0 else x)
ch_data.drop(ch_data[ch_data['existing_foir'] < 0].index, inplace = True)

# %%
ch_data.total_accounts.fillna(0, inplace= True) 
ch_data.negative_status_accounts.fillna(0, inplace= True) 
ch_data.positive_status_accounts.fillna(0, inplace= True) 
ch_data.open_accounts.fillna(0, inplace= True) 
ch_data.closed_accounts.fillna(0, inplace= True) 
ch_data.max_dpd.fillna(0, inplace= True) 
ch_data.credit_utilization.fillna(0, inplace= True) 
ch_data.enquiries_made.fillna(0, inplace= True) 
ch_data.seasoning.fillna(0, inplace= True) 
ch_data.portfolio_mix_secured.fillna(0, inplace= True) 
ch_data.portfolio_mix_unsecured.fillna(0, inplace= True) 
ch_data.related_accounts.fillna(0, inplace= True) 
ch_data.annual_income.fillna(30000, inplace= True) 
ch_data.calculated_emi.fillna(0, inplace= True) 
ch_data.minor_issues.fillna(0, inplace= True) 
ch_data.ontime_payment_percentage.fillna(0, inplace= True) 
ch_data.no_of_delayed_payments.fillna(0, inplace= True) 
ch_data.no_of_delayed_payments_on_active_accounts.fillna(0, inplace= True) 
ch_data.no_of_active_accounts.fillna(0, inplace= True) 
ch_data.existing_foir.fillna(0, inplace= True) 
ch_data.credit_utilization_avg.fillna(0, inplace= True)

# %%
ch_data['p_credit_score'] = np.where(ch_data['p_credit_score']>775,775,ch_data['p_credit_score'])
ch_data['total_accounts'] = np.where(ch_data['total_accounts']>47,47,ch_data['total_accounts'])
ch_data['negative_status_accounts'] = np.where(ch_data['negative_status_accounts']>2,2,ch_data['negative_status_accounts'])
ch_data['positive_status_accounts'] = np.where(ch_data['positive_status_accounts']>23,23,ch_data['positive_status_accounts'])
ch_data['open_accounts'] = np.where(ch_data['open_accounts']>14,14,ch_data['open_accounts'])
ch_data['closed_accounts'] = np.where(ch_data['closed_accounts']>17,17,ch_data['closed_accounts'])
ch_data['max_dpd'] = np.where(ch_data['max_dpd']>120,120,ch_data['max_dpd'])
ch_data['credit_utilization'] = np.where(ch_data['credit_utilization']>100,100,ch_data['credit_utilization'])
ch_data['enquiries_made'] = np.where(ch_data['enquiries_made']>13,13,ch_data['enquiries_made'])
ch_data['seasoning'] = np.where(ch_data['seasoning']>8,8,ch_data['seasoning'])
ch_data['portfolio_mix_secured'] = np.where(ch_data['portfolio_mix_secured']>1,1,ch_data['portfolio_mix_secured'])
ch_data['portfolio_mix_unsecured'] = np.where(ch_data['portfolio_mix_unsecured']>1,1,ch_data['portfolio_mix_unsecured'])
ch_data['related_accounts'] = np.where(ch_data['related_accounts']>5,5,ch_data['related_accounts'])
ch_data['annual_income'] = np.where(ch_data['annual_income']>560000,560000,ch_data['annual_income'])
ch_data['calculated_emi'] = np.where(ch_data['calculated_emi']>75000,75000,ch_data['calculated_emi'])
ch_data['minor_issues'] = np.where(ch_data['minor_issues']>10,10,ch_data['minor_issues'])
ch_data['no_of_delayed_payments'] = np.where(ch_data['no_of_delayed_payments']>45,45,ch_data['no_of_delayed_payments'])
ch_data['no_of_delayed_payments_on_active_accounts'] = np.where(ch_data['no_of_delayed_payments_on_active_accounts']>45,45,ch_data['no_of_delayed_payments_on_active_accounts'])
ch_data['no_of_active_accounts'] = np.where(ch_data['no_of_active_accounts']>10,10,ch_data['no_of_active_accounts'])
ch_data['existing_foir'] = np.where(ch_data['existing_foir']>3500,3500,ch_data['existing_foir'])
ch_data['credit_utilization_avg'] = np.where(ch_data['credit_utilization_avg']>100,100,ch_data['credit_utilization_avg'])
ch_data['is_saleable'] = np.where(ch_data['is_saleable']>4,4,ch_data['is_saleable'])

# %%
ch_data.columns
# Out:
# Index(['customer_profile_id', 'user_id', 'p_credit_score', 'p_occupation',
#        'p_equifax_income', 'p_customer_type', 'total_accounts',
#        'negative_status_accounts', 'positive_status_accounts', 'open_accounts',
#        'closed_accounts', 'max_dpd', 'credit_utilization', 'enquiries_made',
#        'seasoning', 'portfolio_mix_secured', 'portfolio_mix_unsecured',
#        'related_accounts', 'annual_income', 'calculated_emi', 'minor_issues',
#        'ontime_payment_percentage', 'no_of_delayed_payments',
#        'no_of_delayed_payments_on_active_accounts', 'no_of_active_accounts',
#        'existing_foir', 'credit_utilization_avg', 'is_saleable', 'sub',
#        'profile_validity'],
#       dtype='object')

# %%
ch_data.annual_income.median()
# Out:
# 30000.0

# %%
ch_data.shape
# Out:
# (12183, 30)

# %%
fig = plt.figure(figsize = (30,40))
ax = fig.gca()
ch_data.hist(ax = ax)
pyplot.show()
# Out:
# C:\Users\Pon kebha.DESKTOP-PI8M9QL\AppData\Local\Temp\ipykernel_176\3830776909.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   ch_data.hist(ax = ax)

# %%
ch_data.isnull().sum()
# Out:
# customer_profile_id                              0
# user_id                                          0
# p_credit_score                                   0
# p_occupation                                 10204
# p_equifax_income                              5736
# p_customer_type                                  0
# total_accounts                                   0
# negative_status_accounts                         0
# positive_status_accounts                         0
# open_accounts                                    0
# closed_accounts                                  0
# max_dpd                                          0
# credit_utilization                               0
# enquiries_made                                   0
# seasoning                                        0
# portfolio_mix_secured                            0
# portfolio_mix_unsecured                          0
# related_accounts                                 0
# annual_income                                    0
# calculated_emi                                   0
# minor_issues                                     0
# ontime_payment_percentage                        0
# no_of_delayed_payments                           0
# no_of_delayed_payments_on_active_accounts        0
# no_of_active_accounts                            0
# existing_foir                                    0
# credit_utilization_avg                           0
# is_saleable                                      0
# sub                                              0
# profile_validity                                 0
# dtype: int64

# %%
''' get_occupation '''
def get_occupation(occupation):
    try:
        if occupation == 9:
            return 'Student'
        elif occupation in [1,2]:
            return 'Salaried'
        elif occupation in [3,4,5,6,7,8]:
            return 'SelfEmployed'
        elif occupation in [10,11]:
            return 'Other'
        else:
            return 'Other'
    except:
        return 'Other'
ch_data['p_occupation'] = ch_data['p_occupation'].apply(lambda x: get_occupation(x))
ch_data['p_occupation'].value_counts()
# Out:
# Other           10204
# Salaried         1030
# SelfEmployed      949
# Name: p_occupation, dtype: int64

# %%
''' get_salary '''
def get_salary(salary):
    try:
        if salary == 1:
            return '<10k'
        elif salary == 2:
            return '10-15k'
        elif salary == 3:
            return '15-20k'
        elif salary == 4:
            return '20-25k'
        elif salary == 5:
            return '25-30k'
        elif salary == 6:
            return '30-35k'
        elif salary == 7:
            return '35-40k'
        elif salary == 8:
            return '40-45k'
        elif salary == 9:
            return '40-45k'
        elif salary == 10:
            return '40-45k'
        elif salary == 11:
            return '40-45k'
        elif salary == 12:
            return '40-45k'
        elif salary == 13:
            return '40-45k'
        elif salary ==14:
            return '40-45k'
        elif salary == 15:
            return '40-45k'
        else:
            return 'Other'
    except:
        return 'Other'
ch_data['p_equifax_income'] = ch_data['p_equifax_income'].apply(lambda x: get_salary(x))
ch_data['p_equifax_income'].value_counts()
# Out:
# Other     5736
# 40-45k    3000
# 15-20k     873
# 10-15k     717
# 20-25k     627
# 25-30k     411
# <10k       352
# 30-35k     238
# 35-40k     229
# Name: p_equifax_income, dtype: int64

# %%
''' get_p_customer_type '''
def get_p_customer_type(type):
    try:
        if type == 1:
            return 'Green'
        elif type == 2:
            return 'Red'
        else:
            return 'Amber'
    except:
        return 'Amber'
ch_data['p_customer_type'] = ch_data['p_customer_type'].apply(lambda x: get_p_customer_type(x))
ch_data['p_customer_type'].value_counts()
# Out:
# Green    6274
# Red      4841
# Amber    1068
# Name: p_customer_type, dtype: int64

# %%
joblib.dump(ch_data, 'ch_clean_data_bl.pkl')
# Out:
# ['ch_clean_data_bl.pkl']

# %%
ch_data.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\style.py:3555: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\style.py:3556: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_06f27_row0_col0, #T_06f27_row1_col1, #T_06f27_row2_col2, #T_06f27_row3_col3, #T_06f27_row4_col4, #T_06f27_row5_col5, #T_06f27_row6_col6, #T_06f27_row7_col7, #T_06f27_row8_col8, #T_06f27_row9_col9, #T_06f27_row10_col10, #T_06f27_row11_col11, #T_06f27_row12_col12, #T_06f27_row13_col13, #T_06f27_row14_col14, #T_06f27_row15_col15, #T_06f27_row16_col16, #T_06f27_row17_col17, #T_06f27_row18_col18, #T_06f27_row19_col19, #T_06f27_row19_col20, #T_06f27_row20_col19, #T_06f27_row20_col20, #T_06f27_row21_col21, #T_06f27_row22_col22, #T_06f27_row23_col23, #T_06f27_row24_col24, #T_06f27_row25_col25 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_06f27_row0_col1, #T_06f27_row1_col5, #T_06f27_row2_col1, #T_06f27_row3_col1, #T_06f27_row4_col1, #T_06f27_row5_col1, #T_06f27_row6_col1, #T_06f27_row7_col1, #T_06f27_row8_col18, #T_06f27_row9_col1, #T_06f27_row10_col1, #T_06f27_row11_col1, #T_06f27_row12_col13, #T_06f27_row13_col12, #T_06f27_row14_col1, #T_06f27_row15_col1, #T_06f27_row16_col1, #T_06f27_row17_col1, #T_06f27_row18_col19, #T_06f27_row18_col20, #T_06f27_row19_col18, #T_06f27_row20_col18, #T_06f27_row21_col1, #T_06f27_row22_col1, #T_06f27_row23_col1, #T_06f27_row24_col1, #T_06f27_row25_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_06f27_row0_col2, #T_06f27_row9_col25, #T_06f27_row12_col17, #T_06f27_row16_col8, #T_06f27_row23_col10, #T_06f27_row25_col9 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_06f27_row0_col3, #T_06f27_row6_col2, #T_06f27_row6_col15, #T_06f27_row7_col9, #T_06f27_row7_col23, #T_06f27_row14_col22, #T_06f27_row21_col19, #T_06f27_row21_col20, #T_06f27_row25_col7 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_06f27_row0_col4, #T_06f27_row9_col19, #T_06f27_row9_col20 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_06f27_row0_col5, #T_06f27_row3_col4, #T_06f27_row11_col25, #T_06f27_row13_col3 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_06f27_row0_col6, #T_06f27_row6_col4, #T_06f27_row21_col2, #T_06f27_row25_col6 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_06f27_row0_col7, #T_06f27_row16_col23, #T_06f27_row17_col14 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_06f27_row0_col8, #T_06f27_row10_col17, #T_06f27_row11_col12 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_06f27_row0_col9, #T_06f27_row0_col15, #T_06f27_row10_col3, #T_06f27_row10_col5, #T_06f27_row11_col15, #T_06f27_row12_col11, #T_06f27_row12_col22, #T_06f27_row15_col7, #T_06f27_row17_col2, #T_06f27_row22_col10, #T_06f27_row22_col23, #T_06f27_row24_col23, #T_06f27_row25_col2 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_06f27_row0_col10, #T_06f27_row2_col16, #T_06f27_row12_col15, #T_06f27_row15_col25, #T_06f27_row25_col23 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_06f27_row0_col11, #T_06f27_row25_col5 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_06f27_row0_col12, #T_06f27_row4_col23, #T_06f27_row24_col0, #T_06f27_row24_col22 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_06f27_row0_col13, #T_06f27_row3_col12, #T_06f27_row4_col5, #T_06f27_row12_col4, #T_06f27_row13_col14, #T_06f27_row16_col4, #T_06f27_row23_col15 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_06f27_row0_col14, #T_06f27_row10_col11, #T_06f27_row18_col7, #T_06f27_row18_col25, #T_06f27_row23_col11 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_06f27_row0_col16, #T_06f27_row9_col21, #T_06f27_row13_col5, #T_06f27_row14_col7, #T_06f27_row18_col6, #T_06f27_row22_col5 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_06f27_row0_col17, #T_06f27_row2_col9, #T_06f27_row12_col10, #T_06f27_row25_col17, #T_06f27_row25_col19, #T_06f27_row25_col20 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_06f27_row0_col18, #T_06f27_row4_col3, #T_06f27_row4_col7, #T_06f27_row7_col15, #T_06f27_row13_col23, #T_06f27_row17_col4, #T_06f27_row17_col22, #T_06f27_row19_col8, #T_06f27_row19_col21, #T_06f27_row20_col8, #T_06f27_row20_col21, #T_06f27_row25_col22 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_06f27_row0_col19, #T_06f27_row0_col20, #T_06f27_row1_col10, #T_06f27_row2_col17, #T_06f27_row22_col24 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_06f27_row0_col21, #T_06f27_row21_col10, #T_06f27_row22_col7, #T_06f27_row23_col6, #T_06f27_row25_col21 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_06f27_row0_col22, #T_06f27_row18_col0, #T_06f27_row19_col3, #T_06f27_row20_col3 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_06f27_row0_col23, #T_06f27_row4_col12, #T_06f27_row19_col23, #T_06f27_row20_col23, #T_06f27_row22_col19, #T_06f27_row22_col20, #T_06f27_row23_col0, #T_06f27_row24_col16 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_06f27_row0_col24, #T_06f27_row8_col24, #T_06f27_row19_col12, #T_06f27_row20_col12 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_06f27_row0_col25 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_06f27_row0_col26, #T_06f27_row1_col26, #T_06f27_row2_col26, #T_06f27_row3_col26, #T_06f27_row4_col26, #T_06f27_row5_col26, #T_06f27_row6_col26, #T_06f27_row7_col26, #T_06f27_row8_col26, #T_06f27_row9_col26, #T_06f27_row10_col26, #T_06f27_row11_col26, #T_06f27_row12_col26, #T_06f27_row13_col26, #T_06f27_row14_col26, #T_06f27_row15_col26, #T_06f27_row16_col26, #T_06f27_row17_col26, #T_06f27_row18_col26, #T_06f27_row19_col26, #T_06f27_row20_col26, #T_06f27_row21_col26, #T_06f27_row22_col26, #T_06f27_row23_col26, #T_06f27_row24_col26, #T_06f27_row25_col26, #T_06f27_row26_col0, #T_06f27_row26_col1, #T_06f27_row26_col2, #T_06f27_row26_col3, #T_06f27_row26_col4, #T_06f27_row26_col5, #T_06f27_row26_col6, #T_06f27_row26_col7, #T_06f27_row26_col8, #T_06f27_row26_col9, #T_06f27_row26_col10, #T_06f27_row26_col11, #T_06f27_row26_col12, #T_06f27_row26_col13, #T_06f27_row26_col14, #T_06f27_row26_col15, #T_06f27_row26_col16, #T_06f27_row26_col17, #T_06f27_row26_col18, #T_06f27_row26_col19, #T_06f27_row26_col20, #T_06f27_row26_col21, #T_06f27_row26_col22, #T_06f27_row26_col23, #T_06f27_row26_col24, #T_06f27_row26_col25, #T_06f27_row26_col26 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_06f27_row1_col0, #T_06f27_row1_col23, #T_06f27_row2_col8, #T_06f27_row8_col22, #T_06f27_row11_col19, #T_06f27_row11_col20 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_06f27_row1_col2, #T_06f27_row10_col16, #T_06f27_row10_col23 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_06f27_row1_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_06f27_row1_col4, #T_06f27_row2_col24, #T_06f27_row8_col5, #T_06f27_row22_col15 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_06f27_row1_col6 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_06f27_row1_col7, #T_06f27_row8_col1, #T_06f27_row10_col12 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_06f27_row1_col8, #T_06f27_row12_col9, #T_06f27_row13_col8, #T_06f27_row13_col19, #T_06f27_row13_col20, #T_06f27_row17_col0, #T_06f27_row24_col25, #T_06f27_row25_col24 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_06f27_row1_col9, #T_06f27_row1_col24, #T_06f27_row1_col25, #T_06f27_row2_col4, #T_06f27_row15_col22, #T_06f27_row18_col8 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_06f27_row1_col11, #T_06f27_row8_col3, #T_06f27_row10_col0, #T_06f27_row24_col13 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_06f27_row1_col12, #T_06f27_row2_col23, #T_06f27_row4_col25, #T_06f27_row13_col24, #T_06f27_row19_col25, #T_06f27_row20_col25 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_06f27_row1_col13, #T_06f27_row15_col8 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_06f27_row1_col14 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_06f27_row1_col15, #T_06f27_row8_col16, #T_06f27_row19_col11, #T_06f27_row20_col11 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_06f27_row1_col16, #T_06f27_row18_col24 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_06f27_row1_col17 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_06f27_row1_col18, #T_06f27_row4_col2, #T_06

# %%
exclude=['profile_validity']

# %%
numerical_columns=list(ch_data.select_dtypes(include='number').columns)
for feature in numerical_columns:
    if feature in exclude:
        pass
    else:
        numerical_columns.remove(feature)
print(numerical_columns)
# Out:
# ['user_id', 'total_accounts', 'positive_status_accounts', 'closed_accounts', 'credit_utilization', 'seasoning', 'portfolio_mix_unsecured', 'annual_income', 'minor_issues', 'no_of_delayed_payments', 'no_of_active_accounts', 'credit_utilization_avg', 'sub', 'profile_validity']

# %%
skewed=[]
def find_skew(data,numerical_columns):
    skew_list={}
    for feature in numerical_columns:
        try:
            try:
                skew_value=(3*(data[feature].mean()-data[feature].median()))/data[feature].std()
                if ((round(skew_value,2)<-3) or (round(skew_value,2)>3)):
                    skew_list[feature]='Skewwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww'
                    skewed.append(feature)
                else:
                    skew_list[feature]=round(skew_value,2)
            except ZeroDivisionError:
                skew_list[feature]='Skewwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww'
                skewed.append(feature)
        except:
            pass
    return skew_list
skew_list=find_skew(ch_data,numerical_columns)
skew_list
# Out:
# {'user_id': -0.83,
#  'total_accounts': 1.08,
#  'positive_status_accounts': 0.31,
#  'closed_accounts': 0.89,
#  'credit_utilization': 1.35,
#  'seasoning': 0.51,
#  'portfolio_mix_unsecured': -1.4,
#  'annual_income': 1.04,
#  'minor_issues': 0.92,
#  'no_of_delayed_payments': 1.75,
#  'no_of_active_accounts': 0.77,
#  'credit_utilization_avg': 1.47,
#  'sub': 2.58,
#  'profile_validity': 'Skewwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww'}

# %%
for i in numerical_columns:
    if i in exclude:
        pass
    else:
        try:
            ch_data[i] =stats.boxcox(array)
        except:
            pass
find_skew(ch_data,numerical_columns)
# Out:
# {'user_id': -0.83,
#  'total_accounts': 1.08,
#  'positive_status_accounts': 0.31,
#  'closed_accounts': 0.89,
#  'credit_utilization': 1.35,
#  'seasoning': 0.51,
#  'portfolio_mix_unsecured': -1.4,
#  'annual_income': 1.04,
#  'minor_issues': 0.92,
#  'no_of_delayed_payments': 1.75,
#  'no_of_active_accounts': 0.77,
#  'credit_utilization_avg': 1.47,
#  'sub': 2.58,
#  'profile_validity': 'Skewwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww'}

# %%
joblib.dump(ch_data, 'ch_transformed_data_bl.pkl')
# Out:
# ['ch_transformed_data_bl.pkl']

# %%
user_ids=pd.concat([ch_data['user_id'].reset_index(drop = True)], axis = 1)
ch_data.drop(['user_id'],axis=1,inplace=True)

# %%
customer_profile_id=pd.concat([ch_data['customer_profile_id'].reset_index(drop = True)], axis = 1)
ch_data.drop(['customer_profile_id'],axis=1,inplace=True)

# %%
categorical_features=list(ch_data.select_dtypes(exclude='number').columns)
categorical_features
# Out:
# ['p_occupation', 'p_equifax_income', 'p_customer_type']

# %%
exemption_features=['sub']

# %%
numeric_features=list(ch_data.select_dtypes(include='number').columns)
numeric_features
flag_features=[]
for feature in exemption_features:
    numeric_features.remove(feature)
for feature in exclude:
    if feature in numeric_features:
        flag_features.append(feature)
        numeric_features.remove(feature)

# %%
id_columns=['user_id','customer_profile_id']
exemption_features=['sub']

# %%
dummies = pd.get_dummies(data = ch_data[categorical_features], drop_first=False)
dummies.columns
# Out:
# Index(['p_occupation_Other', 'p_occupation_Salaried',
#        'p_occupation_SelfEmployed', 'p_equifax_income_10-15k',
#        'p_equifax_income_15-20k', 'p_equifax_income_20-25k',
#        'p_equifax_income_25-30k', 'p_equifax_income_30-35k',
#        'p_equifax_income_35-40k', 'p_equifax_income_40-45k',
#        'p_equifax_income_<10k', 'p_equifax_income_Other',
#        'p_customer_type_Amber', 'p_customer_type_Green',
#        'p_customer_type_Red'],
#       dtype='object')

# %%
'''Scaling numeric features'''
standard_scalar = StandardScaler(with_mean=True,with_std=True)
standard_scalar.fit(ch_data[numeric_features])
numeric_data_scaled = standard_scalar.transform(ch_data[numeric_features])
numeric_data_scaled = pd.DataFrame(numeric_data_scaled,columns=numeric_features)
numeric_data_scaled.head()
# Out:
#    p_credit_score  total_accounts  negative_status_accounts  \
# 0           -2.98           -0.77                     -0.75
# 1            0.54            2.09                     -0.75
# 2           -2.98           -1.11                     -0.75
# 3            0.79           -0.83                     -0.75
# 4            0.54           -0.83                     -0.75
#
#    positive_status_accounts  open_accounts  closed_accounts  max_dpd  \
# 0                     -0.81          -0.56            -0.91    -0.23
# 1                      1.31          -0.33             1.38    -0.23
# 2                     -1.39          -1.25            -1.21    -0.23
# 3                     -0.92          -0.79            -0.91    -0.23
# 4                     -0.81          -0.33            -1.06    -0.23
#
#    credit_utilization  enquiries_made  seasoning  portfolio_mix_secured  \
# 0                1.55            1.16       0.22                  -0.56
# 1               -0.45           -0.62      -0.17                  -0.56
# 2               -0.45           -0.62      -0.96                  -0.56
# 3               -0.45           -0.17      -0.96                  -0.56
# 4               -0.45           -0.62      -0.17                  -0.56
#
#    portfolio_mix_unsecured  related_accounts  annual_income  calculated_emi  \
# 0                     0.87              0.07          -0.19            0.84
# 1                     0.87             -0.61          -0.44           -0.66
# 2                    -1.50             -0.61          -0.35           -0.81
# 3                    -1.50             -0.61          -0.35           -0.81
# 4                     0.87             -0.61          -0.19            0.78
#
#    minor_issues  ontime_payment_percentage  no_of_delayed_payments  \
# 0         -0.78                       0.75                   -0.58
# 1          0.17                       0.75                   -0.58
# 2         -0.78                      -1.87                   -0.58
# 3          0.17                      -1.87                   -0.58
# 4         -0.78                       0.75                   -0.58
#
#    no_of_delayed_payments_on_active_accounts  no_of_active_accounts  \
# 0                                      -0.58                  -0.26
# 1                                      -0.58                  -0.57
# 2                                      -0.58                  -1.18
# 3                                      -0.58                  -1.18
# 4                                      -0.58                   0.05
#
#    existing_foir  credit_utilization_avg  is_saleable
# 0           0.53                    1.52        -0.49
# 1          -0.27                   -0.49        -0.49
# 2          -0.53                   -0.49        -0.49
# 3          -0.53                   -0.49        -0.49
# 4           0.49                   -0.49        -0.49

# %%
'''Concatenating all features'''
processed_dataset = pd.concat([user_ids['user_id'].reset_index(drop = True), 
                               customer_profile_id['customer_profile_id'].reset_index(drop = True), 
                               numeric_data_scaled.reset_index(drop = True),
                               ch_data[flag_features].reset_index(drop = True),
                               dummies.reset_index(drop = True),
                              ch_data[exemption_features].reset_index(drop = True)
                              ], axis=1)
processed_dataset.shape
# Out:
# (12183, 42)

# %%
joblib.dump(processed_dataset, 'ch_processed_data_bl.pkl')
# Out:
# ['ch_processed_data_bl.pkl']

# %%
processed_dataset.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\style.py:3555: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\style.py:3556: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_1f0cd_row0_col0, #T_1f0cd_row1_col1, #T_1f0cd_row2_col2, #T_1f0cd_row3_col3, #T_1f0cd_row4_col4, #T_1f0cd_row5_col5, #T_1f0cd_row6_col6, #T_1f0cd_row7_col7, #T_1f0cd_row8_col8, #T_1f0cd_row9_col9, #T_1f0cd_row10_col10, #T_1f0cd_row11_col11, #T_1f0cd_row12_col12, #T_1f0cd_row13_col13, #T_1f0cd_row14_col14, #T_1f0cd_row15_col15, #T_1f0cd_row16_col16, #T_1f0cd_row17_col17, #T_1f0cd_row18_col18, #T_1f0cd_row19_col19, #T_1f0cd_row19_col20, #T_1f0cd_row20_col19, #T_1f0cd_row20_col20, #T_1f0cd_row21_col21, #T_1f0cd_row22_col22, #T_1f0cd_row23_col23, #T_1f0cd_row24_col24, #T_1f0cd_row26_col26, #T_1f0cd_row27_col27, #T_1f0cd_row28_col28, #T_1f0cd_row29_col29, #T_1f0cd_row30_col30, #T_1f0cd_row31_col31, #T_1f0cd_row32_col32, #T_1f0cd_row33_col33, #T_1f0cd_row34_col34, #T_1f0cd_row35_col35, #T_1f0cd_row36_col36, #T_1f0cd_row37_col37, #T_1f0cd_row38_col38, #T_1f0cd_row39_col39, #T_1f0cd_row40_col40, #T_1f0cd_row41_col41 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1f0cd_row0_col1, #T_1f0cd_row0_col23, #T_1f0cd_row8_col18, #T_1f0cd_row10_col12, #T_1f0cd_row31_col38, #T_1f0cd_row32_col36, #T_1f0cd_row33_col1, #T_1f0cd_row33_col27, #T_1f0cd_row33_col39, #T_1f0cd_row33_col41 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_1f0cd_row0_col2, #T_1f0cd_row8_col9, #T_1f0cd_row8_col26, #T_1f0cd_row8_col30, #T_1f0cd_row10_col35, #T_1f0cd_row11_col4, #T_1f0cd_row11_col40, #T_1f0cd_row19_col0, #T_1f0cd_row20_col0, #T_1f0cd_row23_col29, #T_1f0cd_row30_col14, #T_1f0cd_row31_col8, #T_1f0cd_row31_col23, #T_1f0cd_row32_col2, #T_1f0cd_row32_col19, #T_1f0cd_row32_col20, #T_1f0cd_row35_col0, #T_1f0cd_row36_col5, #T_1f0cd_row36_col7, #T_1f0cd_row37_col17, #T_1f0cd_row37_col30, #T_1f0cd_row39_col24 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_1f0cd_row0_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_1f0cd_row0_col4, #T_1f0cd_row8_col0, #T_1f0cd_row29_col16, #T_1f0cd_row31_col30, #T_1f0cd_row32_col33, #T_1f0cd_row32_col34, #T_1f0cd_row33_col14, #T_1f0cd_row33_col16, #T_1f0cd_row33_col28, #T_1f0cd_row34_col14, #T_1f0cd_row34_col24, #T_1f0cd_row34_col28 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_1f0cd_row0_col5, #T_1f0cd_row1_col0, #T_1f0cd_row2_col38, #T_1f0cd_row3_col37, #T_1f0cd_row4_col39, #T_1f0cd_row5_col37, #T_1f0cd_row6_col37, #T_1f0cd_row7_col37, #T_1f0cd_row8_col39, #T_1f0cd_row9_col0, #T_1f0cd_row10_col37, #T_1f0cd_row11_col37, #T_1f0cd_row12_col13, #T_1f0cd_row13_col12, #T_1f0cd_row14_col0, #T_1f0cd_row15_col37, #T_1f0cd_row16_col0, #T_1f0cd_row17_col0, #T_1f0cd_row18_col38, #T_1f0cd_row19_col39, #T_1f0cd_row20_col39, #T_1f0cd_row21_col37, #T_1f0cd_row22_col37, #T_1f0cd_row23_col0, #T_1f0cd_row24_col39, #T_1f0cd_row26_col27, #T_1f0cd_row27_col26, #T_1f0cd_row28_col26, #T_1f0cd_row29_col37, #T_1f0cd_row30_col37, #T_1f0cd_row31_col37, #T_1f0cd_row32_col37, #T_1f0cd_row33_col37, #T_1f0cd_row34_col37, #T_1f0cd_row35_col37, #T_1f0cd_row36_col37, #T_1f0cd_row37_col35, #T_1f0cd_row38_col2, #T_1f0cd_row39_col40, #T_1f0cd_row40_col39, #T_1f0cd_row41_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_1f0cd_row0_col6, #T_1f0cd_row17_col38 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_1f0cd_row0_col7, #T_1f0cd_row17_col37 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_1f0cd_row0_col8, #T_1f0cd_row8_col16, #T_1f0cd_row10_col41, #T_1f0cd_row12_col9, #T_1f0cd_row13_col8, #T_1f0cd_row13_col19, #T_1f0cd_row13_col20, #T_1f0cd_row17_col1, #T_1f0cd_row23_col27, #T_1f0cd_row31_col3, #T_1f0cd_row41_col24 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_1f0cd_row0_col9, #T_1f0cd_row0_col24, #T_1f0cd_row0_col41, #T_1f0cd_row8_col38, #T_1f0cd_row29_col38, #T_1f0cd_row31_col29, #T_1f0cd_row32_col26 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_1f0cd_row0_col10, #T_1f0cd_row1_col19, #T_1f0cd_row1_col20, #T_1f0cd_row12_col34, #T_1f0cd_row15_col12, #T_1f0cd_row16_col32, #T_1f0cd_row16_col33, #T_1f0cd_row30_col5, #T_1f0cd_row38_col5 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_1f0cd_row0_col11, #T_1f0cd_row10_col4, #T_1f0cd_row15_col29, #T_1f0cd_row23_col26, #T_1f0cd_row30_col31, #T_1f0cd_row31_col0, #T_1f0cd_row31_col26, #T_1f0cd_row32_col1, #T_1f0cd_row32_col16, #T_1f0cd_row32_col28, #T_1f0cd_row33_col11, #T_1f0cd_row34_col13, #T_1f0cd_row36_col9, #T_1f0cd_row36_col11, #T_1f0cd_row36_col12, #T_1f0cd_row36_col13, #T_1f0cd_row37_col16, #T_1f0cd_row41_col29 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_1f0cd_row0_col12, #T_1f0cd_row6_col26, #T_1f0cd_row11_col29, #T_1f0cd_row12_col39, #T_1f0cd_row13_col24, #T_1f0cd_row14_col33, #T_1f0cd_row17_col31, #T_1f0cd_row17_col33, #T_1f0cd_row29_col2, #T_1f0cd_row30_col40, #T_1f0cd_row32_col7, #T_1f0cd_row35_col38, #T_1f0cd_row37_col24, #T_1f0cd_row41_col39, #T_1f0cd_row41_col40 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_1f0cd_row0_col13, #T_1f0cd_row8_col23, #T_1f0cd_row8_col36, #T_1f0cd_row11_col19, #T_1f0cd_row11_col20, #T_1f0cd_row14_col29, #T_1f0cd_row15_col32, #T_1f0cd_row19_col37, #T_1f0cd_row20_col37, #T_1f0cd_row29_col17, #T_1f0cd_row30_col8, #T_1f0cd_row30_col12, #T_1f0cd_row30_col28, #T_1f0cd_row31_col18, #T_1f0cd_row37_col29 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_1f0cd_row0_col14, #T_1f0cd_row9_col38, #T_1f0cd_row11_col0, #T_1f0cd_row23_col38, #T_1f0cd_row33_col29, #T_1f0cd_row33_col31, #T_1f0cd_row34_col31 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_1f0cd_row0_col15, #T_1f0cd_row9_col26, #T_1f0cd_row31_col36, #T_1f0cd_row33_col2, #T_1f0cd_row33_col13, #T_1f0cd_row33_col23, #T_1f0cd_row34_col1, #T_1f0cd_row34_col2, #T_1f0cd_row34_col17, #T_1f0cd_row34_col18, #T_1f0cd_row34_col41 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_1f0cd_row0_col16, #T_1f0cd_row21_col38, #T_1f0cd_row23_col37, #T_1f0cd_row36_col35 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_1f0cd_row0_col17, #T_1f0cd_row13_col37, #T_1f0cd_row33_col8, #T_1f0cd_row34_col39, #T_1f0cd_row36_col0 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_1f0cd_row0_col18, #T_1f0cd_row1_col27, #T_1f0cd_row8_col34, #T_1f0cd_row9_col31, #T_1f0cd_row17_col26, #T_1f0cd_row31_col12, #T_1f0cd_row31_col28, #T_1f0cd_row32_col13, #T_1f0cd_row32_col40, #T_1f0cd_row33_col3, #T_1f0cd_row33_col5, #T_1f0cd_row33_col7, #T_1f0cd_row34_col3, #T_1f0cd_row41_col31 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_1f0cd_row0_col19, #T_1f0cd_row0_col20, #T_1f0cd_row0_col22, #T_1f0cd_row8_col37, #T_1f0cd_row10_col28, #T_1f0cd_row10_col40, #T_1f0cd_row29_col1, #T_1f0cd_row32_col8, #T_1f0cd_row33_col17, #T_1f0cd_row36_col8, #T_1f0cd_row41_col30 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_1f0cd_row0_col21, #T_1f0cd_row11_col38, #T_1f0cd_row13_col38 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_1f0cd_row0_col25, #T_1f0cd_row1_col25, #T_1f0cd_row2_col25, #T_1f0cd_row3_col25, #T_1f0cd_row4_col25, #T_1f0cd_row5_col25, #T_1f0cd_row6_col25, #T_1f0cd_row7_col25, #T_1f0cd_row8_col25, #T_1f0cd_row9_col25, #T_1f0cd_row10_col25, #T_1f0cd_row11_col25, #T_1f0cd_row12_col25, #T_1f0cd_row13_col25, #T_1f0cd_row14_col25, #T_1f0cd_row15_col25, #T_1f0cd_row16_col25, #T_1f0cd_row17_col25, #T_1f0cd_row18_col25, #T_1f0cd_row19_col25, #T_1f0cd_row20_col25, #T_1f0cd_row21_col25, #T_1f0cd_row22_col25, #T_1f0cd_row23_col25, #T_1f0cd_row24_col25, #T_1f0cd_row25_col0, #T_1f0cd_row25_col1, #T_1f0cd_row25_col2, #T_1f0cd_row25_col3, #T_1f0cd_row25_col4, #T_1f0cd_row25_col5, #T_1f0cd_row25_col6, #T_1f0cd_row25_col7, #T_1f0cd_row25_col8, #T_1f0cd_row25_col9, #T_1f0cd_row25_col10, #T_1f0cd_row25_col11, #T_1f0cd_row25_col12, #T_1f0cd_row25_col13, #T_1f0cd_row25_col14, #T_1f0cd_row25_col15, #T_1f0cd_row25_col16, #T_1f0cd_row25_col17, #T_1f0cd_row25_col18, #T_1f0cd_row25_col19, #T_1f0cd_row25_col20, #T_1f0cd_row25_col21, #T_1f0cd_row25_col22, #T_1f0cd_row25_col23, #T_1f0cd_row25_col24, #T_1f0cd_row25_col25, #T_1f0cd_row25_col26, #T_1f0cd_row25_col27, #T_1f0cd_row25_col28, #T_1f0cd_row25_col29, #T_1f0cd_row25_col30, #T_1f0cd_row25_col31, #T_1f0cd_row25_col32, #T_1f0cd_r

# %%
ch_data.describe(percentiles=[0.01,0.05,0.10,0.25,0.5,0.75,0.9,0.95,0.99],datetime_is_numeric=True).transpose()
# Out:
#                                              count     mean       std  min  \
# p_credit_score                            12183.00   613.15    206.01 0.00
# total_accounts                            12183.00    16.28     14.71 0.00
# negative_status_accounts                  12183.00     0.61      0.81 0.00
# positive_status_accounts                  12183.00    11.87      8.53 0.00
# open_accounts                             12183.00     5.43      4.34 0.00
# closed_accounts                           12183.00     7.95      6.57 0.00
# max_dpd                                   12183.00     5.13     22.69 0.00
# credit_utilization                        12183.00    13.52     29.95 0.00
# enquiries_made                            12183.00     1.39      2.25 0.00
# seasoning                                 12183.00     2.43      2.54 0.00
# portfolio_mix_secured                     12183.00     0.16      0.28 0.00
# portfolio_mix_unsecured                   12183.00     0.63      0.42 0.00
# related_accounts                          12183.00     0.89      1.46 0.00
# annual_income                             12183.00 75551.12 131804.73 1.00
# calculated_emi                            12183.00 22333.17  27546.67 0.00
# minor_issues                              12183.00     1.64      2.11 0.00
# ontime_payment_percentage                 12183.00    71.23     38.18 0.00
# no_of_delayed_payments                    12183.00     7.56     12.96 0.00
# no_of_delayed_payments_on_active_accounts 12183.00     7.56     12.96 0.00
# no_of_active_accounts                     12183.00     3.82      3.23 0.00
# existing_foir                             12183.00   544.68   1032.50 0.00
# credit_utilization_avg                    12183.00    14.63     29.91 0.00
# is_saleable                               12183.00     0.44      0.90 0.00
# sub                                       12183.00     0.43      0.49 0.00
# profile_validity                          12183.00     1.00      0.00 1.00
#
#                                                1%       5%      10%      25%  \
# p_credit_score                               0.00     0.00   500.00   575.00
# total_accounts                               0.00     0.00     1.00     4.00
# negative_status_accounts                     0.00     0.00     0.00     0.00
# positive_status_accounts                     0.00     0.00     1.00     4.00
# open_accounts                                0.00     0.00     1.00     2.00
# closed_accounts                              0.00     0.00     0.00     2.00
# max_dpd                                      0.00     0.00     0.00     0.00
# credit_utilization                           0.00     0.00     0.00     0.00
# enquiries_made                               0.00     0.00     0.00     0.00
# seasoning                                    0.00     0.00     0.00     0.00
# portfolio_mix_secured                        0.00     0.00     0.00     0.00
# portfolio_mix_unsecured                      0.00     0.00     0.00     0.00
# related_accounts                             0.00     0.00     0.00     0.00
# annual_income                             2173.36 14000.00 16700.00 30000.00
# calculated_emi                               0.00     0.00     0.00  1126.23
# minor_issues                                 0.00     0.00     0.00     0.00
# ontime_payment_percentage                    0.00     0.00     0.00    50.00
# no_of_delayed_payments                       0.00     0.00     0.00     0.00
# no_of_delayed_payments_on_active_accounts    0.00     0.00     0.00     0.00
# no_of_active_accounts                        0.00     0.00     0.00     1.00
# existing_foir                                0.00     0.00     0.00     0.00
# credit_utilization_avg                       0.00     0.00     0.00     0.00
# is_saleable                                  0.00     0.00     0.00     0.00
# sub                                          0.00     0.00     0.00     0.00
# profile_validity                             1.00     1.00     1.00     1.00
#
#                                                50%      75%       90%  \
# p_credit_score                              675.00   725.00    775.00
# total_accounts                               11.00    25.00     45.00
# negative_status_accounts                      0.00     1.00      2.00
# positive_status_accounts                     11.00    23.00     23.00
# open_accounts                                 4.00     8.00     13.00
# closed_accounts                               6.00    16.00     17.00
# max_dpd                                       0.00     0.00      0.00
# credit_utilization                            0.00     0.00     73.45
# enquiries_made                                0.00     2.00      4.00
# seasoning                                     2.00     4.00      7.00
# portfolio_mix_secured                         0.00     0.22      0.50
# portfolio_mix_unsecured                       0.83     1.00      1.00
# related_accounts                              0.00     1.00      3.00
# annual_income                             30000.00 40000.00 200000.00
# calculated_emi                             8241.68 36112.46  75000.00
# minor_issues                                  1.00     2.00      4.00
# ontime_payment_percentage                    94.44   100.00    100.00
# no_of_delayed_payments                        0.00    10.00     28.00
# no_of_delayed_payments_on_active_accounts     0.00    10.00     28.00
# no_of_active_accounts                         3.00     6.00     10.00
# existing_foir                                 0.00   511.39   2344.07
# credit_utilization_avg                        0.00     4.00     71.00
# is_saleable                                   0.00     1.00      2.00
# sub                                           0.00     1.00      1.00
# profile_validity                              1.00     1.00      1.00
#
#                                                 95%       99%       max
# p_credit_score                               775.00    775.00    775.00
# total_accounts                                47.00     47.00     47.00
# negative_status_accounts                       2.00      2.00      2.00
# positive_status_accounts                      23.00     23.00     23.00
# open_accounts                                 14.00     14.00     14.00
# closed_accounts                               17.00     17.00     17.00
# max_dpd                                        0.00    120.00    120.00
# credit_utilization                            96.31    100.00    100.00
# enquiries_made                                 6.00     11.00     13.00
# seasoning                                      8.00      8.00      8.00
# portfolio_mix_secured                          1.00      1.00      1.00
# portfolio_mix_unsecured                        1.00      1.00      1.00
# related_accounts                               5.00      5.00      5.00
# annual_income                             500000.00 560000.00 560000.00
# calculated_emi                             75000.00  75000.00  75000.00
# minor_issues                                   6.00     10.00     10.00
# ontime_payment_percentage                    100.00    100.00    100.00
# no_of_delayed_payments                        44.90     45.00     45.00
# no_of_delayed_payments_on_active_accounts     44.90     45.00     45.00
# no_of_active_accounts                         10.00     10.00     10.00
# existing_foir                               3500.00   3500.00   3500.00
# credit_utilization_avg                        97.00    100.00    100.00
# is_saleable                                    2.90      4.00      4.00
# sub                                            1.00      1.00      1.00
# profile_validity                               1.00      1.00      1.00

# %%
'''Replace Infinite'''
processed_dataset = processed_dataset.replace([np.inf, -np.inf], np.nan).dropna(axis=0)
processed_dataset.shape
# Out:
# (12183, 42)

# %%
data=processed_dataset[[
'p_equifax_income_35-40k',
'p_equifax_income_<10k',
'p_equifax_income_30-35k',
'p_customer_type_Amber',
'p_equifax_income_20-25k',
'p_equifax_income_25-30k',
'max_dpd',
'p_equifax_income_10-15k',
'p_equifax_income_15-20k',
'p_customer_type_Red',
'p_customer_type_Green',
'p_occupation_Salaried',
'p_equifax_income_Other',
'p_occupation_SelfEmployed',
'p_occupation_Other',
'p_equifax_income_40-45k',
'negative_status_accounts',
'is_saleable',
'credit_utilization',
'credit_utilization_avg',
'portfolio_mix_secured',
'no_of_delayed_payments_on_active_accounts',
'no_of_delayed_payments',
'related_accounts',
'portfolio_mix_unsecured',
'open_accounts',
'enquiries_made',
'no_of_active_accounts',
'minor_issues',
'closed_accounts',
'annual_income',
'existing_foir',
'seasoning',
'ontime_payment_percentage',
'p_credit_score',
'positive_status_accounts',
'total_accounts',
'calculated_emi',
]]

# %%
'''  Splitting test and train data '''
data=processed_dataset.drop(['customer_profile_id','profile_validity'],axis=1)

X = data.loc[:,data.columns != 'sub']
y = data['sub']
train_X_u,test_X_u,train_y,test_y = train_test_split(X,y,random_state=13,test_size=0.1)
train_X = train_X_u.loc[:,train_X_u.columns != 'user_id']
test_X = test_X_u.loc[:,test_X_u.columns != 'user_id']

# %%
train_X.head()
# Out:
#        p_credit_score  total_accounts  negative_status_accounts  \
# 517              0.54           -0.36                      0.49
# 5515             0.30           -0.83                      1.72
# 7731            -0.19           -0.09                      1.72
# 11326           -0.31            0.66                      1.72
# 5557            -2.98           -1.11                     -0.75
#
#        positive_status_accounts  open_accounts  closed_accounts  max_dpd  \
# 517                       -0.22          -0.33            -0.15    -0.23
# 5515                      -1.16          -0.56            -1.06     3.74
# 7731                       0.13          -0.10             0.31    -0.23
# 11326                      0.72           1.05             1.23    -0.23
# 5557                      -1.39          -1.25            -1.21    -0.23
#
#        credit_utilization  enquiries_made  seasoning  portfolio_mix_secured  \
# 517                 -0.45            0.72       0.22                   1.85
# 5515                -0.45           -0.62      -0.96                  -0.56
# 7731                -0.45           -0.62      -0.96                  -0.56
# 11326               -0.45            0.27      -0.56                   3.04
# 5557                -0.45           -0.62      -0.96                  -0.56
#
#        portfolio_mix_unsecured  related_accounts  annual_income  \
# 517                      -0.72             -0.61          -0.54
# 5515                     -1.50             -0.61          -0.35
# 7731                      0.87              2.80           0.56
# 11326                    -1.50             -0.61          -0.40
# 5557                     -1.50             -0.61          -0.35
#
#        calculated_emi  minor_issues  ontime_payment_percentage  \
# 517             -0.71         -0.78                       0.10
# 5515            -0.74          0.17                      -1.87
# 7731             0.15         -0.31                      -0.72
# 11326           -0.45          1.59                      -0.84
# 5557            -0.81         -0.78                      -1.87
#
#        no_of_delayed_payments  no_of_delayed_payments_on_active_accounts  \
# 517                      1.11                                       1.11
# 5515                     1.11                                       1.11
# 7731                     2.89                                       2.89
# 11326                    2.89                                       2.89
# 5557                    -0.58                                      -0.58
#
#        no_of_active_accounts  existing_foir  credit_utilization_avg  \
# 517                     0.05           0.09                   -0.49
# 5515                   -0.87          -0.53                   -0.49
# 7731                    0.05          -0.32                   -0.49
# 11326                   0.36          -0.03                   -0.49
# 5557                   -1.18          -0.53                   -0.49
#
#        is_saleable  p_occupation_Other  p_occupation_Salaried  \
# 517           0.62                   1                      0
# 5515          0.62                   1                      0
# 7731          0.62                   1                      0
# 11326         1.73                   1                      0
# 5557         -0.49                   1                      0
#
#        p_occupation_SelfEmployed  p_equifax_income_10-15k  \
# 517                            0                        0
# 5515                           0                        0
# 7731                           0                        0
# 11326                          0                        0
# 5557                           0                        0
#
#        p_equifax_income_15-20k  p_equifax_income_20-25k  \
# 517                          0                        0
# 5515                         0                        0
# 7731                         0                        0
# 11326                        0                        1
# 5557                         0                        0
#
#        p_equifax_income_25-30k  p_equifax_income_30-35k  \
# 517                          0                        0
# 5515                         0                        0
# 7731                         0                        0
# 11326                        0                        0
# 5557                         0                        0
#
#        p_equifax_income_35-40k  p_equifax_income_40-45k  \
# 517                          0                        0
# 5515                         0                        0
# 7731                         0                        1
# 11326                        0                        0
# 5557                         0                        0
#
#        p_equifax_income_<10k  p_equifax_income_Other  p_customer_type_Amber  \
# 517                        1                       0                      0
# 5515                       0                       1                      0
# 7731                       0                       0                      0
# 11326                      0                       0                      0
# 5557                       0                       1                      1
#
#        p_customer_type_Green  p_customer_type_Red
# 517                        0                    1
# 5515                       0                    1
# 7731                       0                    1
# 11326                      0                    1
# 5557                       0                    0

# %%
#RandomForest
''' Tuning Grid '''
gridParams = {
#                 'n_estimators': [100],
#                 'max_features':['sqrt'],
#                 'bootstrap': [True],
                'random_state' : [12],
#                 'warm_start':[False],
                'criterion':['gini', 'entropy'],
#                 'max_depth':[47],
                'min_samples_split':[0.00000002,0.00000003,0.00000004,0.00000005],
                'min_samples_leaf':[0.0000002,0.0000003,0.0000004,0.0000005]
             }

'''Model Object'''
model2 = RandomForestClassifier()

''' Grid Formation '''
grid = RandomizedSearchCV(estimator = model2 , param_distributions= gridParams, verbose = 2, cv = 3, n_iter=1000)
grid.fit(train_X, train_y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:292: UserWarning: The total space of parameters 32 is smaller than n_iter=1000. Running 32 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=2e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=2e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=2e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=3e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=3e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# [CV] END criterion=gini, min_samples_leaf=3e-07, min_samples_split=2e-08, random_state=12; total time=   0.8s
# [CV] END criterion=gini, min_samples_leaf=3e-07, min_samples_split=2e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=3e-07, min_samples_split=2e-08, random_state=12; total time=   0.8s
# [CV] END criterion=gini, min_samples_leaf=3e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=gini, min_samples_leaf=3e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=gini, min_samples_leaf=3e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=gini, min_samples_leaf=3e-07, min_samples_split=4e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=3e-07, min_samples_split=4e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=3e-07, min_samples_split=4e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=3e-07, min_samples_split=5e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=3e-07, min_samples_split=5e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=3e-07, min_samples_split=5e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=4e-07, min_samples_split=2e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=4e-07, min_samples_split=2e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=4e-07, min_samples_split=2e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=4e-07, min_samples_split=3e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=4e-07, min_samples_split=3e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=4e-07, min_samples_split=3e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=4e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=gini, min_samples_leaf=4e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=gini, min_samples_leaf=4e-07, min_samples_split=4e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=4e-07, min_samples_split=5e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=4e-07, min_samples_split=5e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=4e-07, min_samples_split=5e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=5e-07, min_samples_split=2e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=5e-07, min_samples_split=2e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=5e-07, min_samples_split=2e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=5e-07, min_samples_split=3e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=5e-07, min_samples_split=3e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=5e-07, min_samples_split=3e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=5e-07, min_samples_split=4e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=5e-07, min_samples_split=4e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=5e-07, min_samples_split=4e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=5e-07, min_samples_split=5e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=5e-07, min_samples_split=5e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=5e-07, min_samples_split=5e-08, random_state=12; total time=   0.6s
# [CV] END criterion=entropy, min_samples_leaf=2e-07, min_samples_split=2e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=2e-07, min_samples_split=2e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=2e-07, min_samples_split=2e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=2e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=2e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=2e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=2e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=2e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=2e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=2e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=2e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=2e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=3e-07, min_samples_split=2e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=3e-07, min_samples_split=2e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=3e-07, min_samples_split=2e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=3e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=3e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=3e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=3e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=3e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=3e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=3e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=3e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=3e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=4e-07, min_samples_split=2e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=4e-07, min_samples_split=2e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=4e-07, min_samples_split=2e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=4e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=4e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=4e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=4e-07, min_samples_split=4e-08, random_state=12; total time=   0.9s
# [CV] END criterion=entropy, min_samples_leaf=4e-07, min_samples_split=4e-08, random_state=12; total time=   0.9s
# [CV] END criterion=entropy, min_samples_leaf=4e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=4e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=4e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=4e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=5e-07, min_samples_split=2e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=5e-07, min_samples_split=2e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=5e-07, min_samples_split=2e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=5e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=5e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=5e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=5e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=5e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=5e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=5e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=5e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=5e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(), n_iter=1000,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'min_samples_leaf': [2e-07, 3e-07,
#                                                              4e-07, 5e-07],
#                                         'min_samples_split': [2e-08, 3e-08,
#                                                               4e-08, 5e-08],
#                                         'random_state': [12]},
#                    verbose=2)

# %%
#RandomForest

'''Model Object'''
model = RandomForestClassifier(criterion='entropy', min_samples_split=0.0005, min_samples_leaf=0.005,  random_state=15)
model.fit(train_X, train_y)
# Out:
# RandomForestClassifier(criterion='entropy', min_samples_leaf=0.005,
#                        min_samples_split=0.0005, random_state=15)

# %%
dict(sorted(dict(zip(grid.feature_names_in_, model.feature_importances_)).items(), key=lambda item: item[1]))
# Out:
# {'p_equifax_income_25-30k': 0.0,
#  'p_equifax_income_30-35k': 0.0,
#  'p_equifax_income_35-40k': 0.0,
#  'max_dpd': 3.112795618716612e-05,
#  'p_equifax_income_20-25k': 8.213789364189963e-05,
#  'p_equifax_income_<10k': 0.00011178646148025369,
#  'p_occupation_Other': 0.0006670683760950198,
#  'p_equifax_income_10-15k': 0.0007307041774546253,
#  'p_occupation_Salaried': 0.0009122782116328662,
#  'p_customer_type_Red': 0.0012876196705030973,
#  'p_occupation_SelfEmployed': 0.0016108064020996697,
#  'negative_status_accounts': 0.0017740783790875056,
#  'p_equifax_income_15-20k': 0.0019160707635270747,
#  'p_customer_type_Green': 0.002250384646540414,
#  'is_saleable': 0.0032028396283184865,
#  'credit_utilization_avg': 0.00431618932679511,
#  'credit_utilization': 0.0046991395365178395,
#  'p_equifax_income_Other': 0.005150565568306497,
#  'p_customer_type_Amber': 0.005209775422591526,
#  'enquiries_made': 0.005647032035704703,
#  'no_of_delayed_payments_on_active_accounts': 0.005853277299063483,
#  'no_of_delayed_payments': 0.006726993793179752,
#  'p_credit_score': 0.013611074117095171,
#  'p_equifax_income_40-45k': 0.016566041141271328,
#  'related_accounts': 0.021344772845665036,
#  'portfolio_mix_secured': 0.02573879345757399,
#  'annual_income': 0.03069295677946647,
#  'open_accounts': 0.03292113276693576,
#  'existing_foir': 0.033873413783195964,
#  'portfolio_mix_unsecured': 0.04073584712447076,
#  'closed_accounts': 0.046980913662858184,
#  'total_accounts': 0.05427310687821542,
#  'minor_issues': 0.05624648560414074,
#  'ontime_payment_percentage': 0.05772372482583968,
#  'no_of_active_accounts': 0.07761031334343012,
#  'seasoning': 0.08629011709900697,
#  'positive_status_accounts': 0.08767985396285329,
#  'calculated_emi': 0.2655315770592543}

# %%
dict(sorted(dict(zip(model.feature_names_in_, model.feature_importances_)).items(), key=lambda item: item[1]))
# Out:
# {'p_equifax_income_25-30k': 0.0,
#  'p_equifax_income_30-35k': 0.0,
#  'p_equifax_income_35-40k': 0.0,
#  'max_dpd': 3.112795618716612e-05,
#  'p_equifax_income_20-25k': 8.213789364189963e-05,
#  'p_equifax_income_<10k': 0.00011178646148025369,
#  'p_occupation_Other': 0.0006670683760950198,
#  'p_equifax_income_10-15k': 0.0007307041774546253,
#  'p_occupation_Salaried': 0.0009122782116328662,
#  'p_customer_type_Red': 0.0012876196705030973,
#  'p_occupation_SelfEmployed': 0.0016108064020996697,
#  'negative_status_accounts': 0.0017740783790875056,
#  'p_equifax_income_15-20k': 0.0019160707635270747,
#  'p_customer_type_Green': 0.002250384646540414,
#  'is_saleable': 0.0032028396283184865,
#  'credit_utilization_avg': 0.00431618932679511,
#  'credit_utilization': 0.0046991395365178395,
#  'p_equifax_income_Other': 0.005150565568306497,
#  'p_customer_type_Amber': 0.005209775422591526,
#  'enquiries_made': 0.005647032035704703,
#  'no_of_delayed_payments_on_active_accounts': 0.005853277299063483,
#  'no_of_delayed_payments': 0.006726993793179752,
#  'p_credit_score': 0.013611074117095171,
#  'p_equifax_income_40-45k': 0.016566041141271328,
#  'related_accounts': 0.021344772845665036,
#  'portfolio_mix_secured': 0.02573879345757399,
#  'annual_income': 0.03069295677946647,
#  'open_accounts': 0.03292113276693576,
#  'existing_foir': 0.033873413783195964,
#  'portfolio_mix_unsecured': 0.04073584712447076,
#  'closed_accounts': 0.046980913662858184,
#  'total_accounts': 0.05427310687821542,
#  'minor_issues': 0.05624648560414074,
#  'ontime_payment_percentage': 0.05772372482583968,
#  'no_of_active_accounts': 0.07761031334343012,
#  'seasoning': 0.08629011709900697,
#  'positive_status_accounts': 0.08767985396285329,
#  'calculated_emi': 0.2655315770592543}

# %%
joblib.dump(grid,"CH_BL_RF_v1.pkl")
# Out:
# ['CH_BL_RF_v1.pkl']

# %%
joblib.dump(model,"CH_BL_RF_v1.1.pkl")
# Out:
# ['CH_BL_RF_v1.1.pkl']

# %%
grid.best_estimator_
# Out:
# RandomForestClassifier(criterion='entropy', min_samples_leaf=2e-07,
#                        min_samples_split=2e-08, random_state=12)

# %%
test_fit2 = grid.predict(test_X)
y_pred=pd.DataFrame(test_fit2)

# %%
test_fit1 = model.predict(test_X)
y_pred1=pd.DataFrame(test_fit1)

# %%
test_fit3 = model.predict(train_X)
y_pred3=pd.DataFrame(test_fit3)

# %%
accuracy_score(test_y, y_pred)
# Out:
# 0.7415914684167351

# %%
accuracy_score(test_y, y_pred1)
# Out:
# 0.7415914684167351

# %%
accuracy_score(train_y, y_pred3)
# Out:
# 0.759850419554907

# %%
cm=ConfusionMatrixDisplay(confusion_matrix(test_y, y_pred))
cm.plot()
plt.show()

# %%
cm=ConfusionMatrixDisplay(confusion_matrix(test_y, y_pred1))
cm.plot()
plt.show()

# %%
cm=ConfusionMatrixDisplay(confusion_matrix(train_y, y_pred3))
cm.plot()
plt.show()

# %%
false_positive_rate, true_positive_rate, threshold1 = roc_curve(test_y, y_pred)
'roc='+str(roc_auc_score(test_y, y_pred))
# Out:
# 'roc=0.7334286275987484'

# %%
false_positive_rate2, true_positive_rate2, threshold2 = roc_curve(test_y, y_pred1)
'roc='+str(roc_auc_score(test_y, y_pred1))
# Out:
# 'roc=0.7294694102677524'

# %%
false_positive_rate3, true_positive_rate3, threshold3 = roc_curve(train_y, y_pred3)
'roc='+str(roc_auc_score(train_y, y_pred3))
# Out:
# 'roc=0.7436659527466434'

# %%
mae = mean_absolute_error(test_y, y_pred)
mse = mean_squared_error(test_y, y_pred)
rmse = np.sqrt(mse) # or mse**(0.5)  
r2 = r2_score(test_y, y_pred)

print("Results of sklearn.metrics:")
print("MAE:",mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R-Squared:", r2)
# Out:
# Results of sklearn.metrics:
# MAE: 0.258408531583265
# MSE: 0.258408531583265
# RMSE: 0.5083389927826362
# R-Squared: -0.048469011615524416

# %%
mae = mean_absolute_error(test_y, y_pred1)
mse = mean_squared_error(test_y, y_pred1)
rmse = np.sqrt(mse) # or mse**(0.5)  
r2 = r2_score(test_y, y_pred1)

print("Results of sklearn.metrics:")
print("MAE:",mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R-Squared:", r2)
# Out:
# Results of sklearn.metrics:
# MAE: 0.258408531583265
# MSE: 0.258408531583265
# RMSE: 0.5083389927826362
# R-Squared: -0.048469011615524416

# %%
mae = mean_absolute_error(train_y, y_pred3)
mse = mean_squared_error(train_y, y_pred3)
rmse = np.sqrt(mse) # or mse**(0.5)  
r2 = r2_score(train_y, y_pred3)

print("Results of sklearn.metrics:")
print("MAE:",mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R-Squared:", r2)
# Out:
# Results of sklearn.metrics:
# MAE: 0.24014958044509302
# MSE: 0.24014958044509302
# RMSE: 0.49005058967936466
# R-Squared: 0.016530130654586972

# %%
plt.subplots(1, figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate, true_positive_rate)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
plt.subplots(1, figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate2, true_positive_rate2)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate 2')
plt.xlabel('False Positive Rate 2')
plt.show()

# %%
plt.subplots(1, figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate3, true_positive_rate3)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate 3')
plt.xlabel('False Positive Rate 3')
plt.show()
