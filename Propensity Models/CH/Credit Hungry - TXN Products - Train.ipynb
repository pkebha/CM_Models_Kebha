# %% [markdown]
# # Credit Hungry for TXN Products Model

# %%
'''Importing Required Libraries'''
import copy
from collections import OrderedDict
import pandas as pd
import lightgbm as lgb
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.options.display.float_format = '{:.2f}'.format
pd.options.mode.chained_assignment = None  # default='warn'
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import scatter_matrix
from matplotlib import pyplot
from scipy import stats
from scipy.stats import norm, skew
from sklearn.preprocessing import PowerTransformer, QuantileTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import LogisticRegression, SGDClassifier,SGDRegressor
from sklearn.ensemble import RandomForestClassifier,VotingClassifier
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import accuracy_score, roc_curve, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.pipeline import make_pipeline
import joblib
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# %%
'''Importing the data for modelling'''
ch_data = pd.read_csv(r"D:\Dbeaver Out\CH_TXN_data_2207_matched_202303161858.csv", na_values=['',' ','NH', 'NA', '[]'], low_memory=False)

# %%
ch_data.drop(['status','report_source', 'report_id', 'report_date', 'filename_prefix', 'pan_no',
        'passport_no', 'driving_license_no', 'voter_id_no', 'ration_card_no',
        'uid_no', 'national_card_no', 'photo_credit_card_no', 'other_id_no',
        'account_type', 'reported_on', 'frequency', 'income_indicator',
        'ability_to_borrow_cc', 'ability_to_borrow_hl', 'ability_to_borrow_pl',
        'ability_to_borrow_al','created_on', 'modified_on', 'modified_by', 'modified_ts','is_active'],axis=1,inplace=True)

# %%
ch_data.annual_income = ch_data.annual_income.apply(lambda x: (x * -1) if x < 0 else x)
ch_data.drop(ch_data[ch_data['existing_foir'] < 0].index, inplace = True)

# %%
ch_data.total_accounts.fillna(0, inplace= True) 
ch_data.negative_status_accounts.fillna(0, inplace= True) 
ch_data.positive_status_accounts.fillna(0, inplace= True) 
ch_data.open_accounts.fillna(0, inplace= True) 
ch_data.closed_accounts.fillna(0, inplace= True) 
ch_data.max_dpd.fillna(0, inplace= True) 
ch_data.credit_utilization.fillna(0, inplace= True) 
ch_data.enquiries_made.fillna(0, inplace= True) 
ch_data.seasoning.fillna(0, inplace= True) 
ch_data.portfolio_mix_secured.fillna(0, inplace= True) 
ch_data.portfolio_mix_unsecured.fillna(0, inplace= True) 
ch_data.related_accounts.fillna(0, inplace= True) 
ch_data.annual_income.fillna(30000, inplace= True) 
ch_data.calculated_emi.fillna(0, inplace= True) 
ch_data.minor_issues.fillna(0, inplace= True) 
ch_data.ontime_payment_percentage.fillna(0, inplace= True) 
ch_data.no_of_delayed_payments.fillna(0, inplace= True) 
ch_data.no_of_delayed_payments_on_active_accounts.fillna(0, inplace= True) 
ch_data.no_of_active_accounts.fillna(0, inplace= True) 
ch_data.existing_foir.fillna(0, inplace= True) 
ch_data.credit_utilization_avg.fillna(0, inplace= True)

# %%
ch_data['p_credit_score'] = np.where(ch_data['p_credit_score']>775,775,ch_data['p_credit_score'])
ch_data['total_accounts'] = np.where(ch_data['total_accounts']>47,47,ch_data['total_accounts'])
ch_data['negative_status_accounts'] = np.where(ch_data['negative_status_accounts']>2,2,ch_data['negative_status_accounts'])
ch_data['positive_status_accounts'] = np.where(ch_data['positive_status_accounts']>23,23,ch_data['positive_status_accounts'])
ch_data['open_accounts'] = np.where(ch_data['open_accounts']>14,14,ch_data['open_accounts'])
ch_data['closed_accounts'] = np.where(ch_data['closed_accounts']>17,17,ch_data['closed_accounts'])
ch_data['max_dpd'] = np.where(ch_data['max_dpd']>120,120,ch_data['max_dpd'])
ch_data['credit_utilization'] = np.where(ch_data['credit_utilization']>100,100,ch_data['credit_utilization'])
ch_data['enquiries_made'] = np.where(ch_data['enquiries_made']>13,13,ch_data['enquiries_made'])
ch_data['seasoning'] = np.where(ch_data['seasoning']>8,8,ch_data['seasoning'])
ch_data['portfolio_mix_secured'] = np.where(ch_data['portfolio_mix_secured']>1,1,ch_data['portfolio_mix_secured'])
ch_data['portfolio_mix_unsecured'] = np.where(ch_data['portfolio_mix_unsecured']>1,1,ch_data['portfolio_mix_unsecured'])
ch_data['related_accounts'] = np.where(ch_data['related_accounts']>5,5,ch_data['related_accounts'])
ch_data['annual_income'] = np.where(ch_data['annual_income']>560000,560000,ch_data['annual_income'])
ch_data['calculated_emi'] = np.where(ch_data['calculated_emi']>75000,75000,ch_data['calculated_emi'])
ch_data['minor_issues'] = np.where(ch_data['minor_issues']>10,10,ch_data['minor_issues'])
ch_data['no_of_delayed_payments'] = np.where(ch_data['no_of_delayed_payments']>45,45,ch_data['no_of_delayed_payments'])
ch_data['no_of_delayed_payments_on_active_accounts'] = np.where(ch_data['no_of_delayed_payments_on_active_accounts']>45,45,ch_data['no_of_delayed_payments_on_active_accounts'])
ch_data['no_of_active_accounts'] = np.where(ch_data['no_of_active_accounts']>10,10,ch_data['no_of_active_accounts'])
ch_data['existing_foir'] = np.where(ch_data['existing_foir']>3500,3500,ch_data['existing_foir'])
ch_data['credit_utilization_avg'] = np.where(ch_data['credit_utilization_avg']>100,100,ch_data['credit_utilization_avg'])
ch_data['is_saleable'] = np.where(ch_data['is_saleable']>4,4,ch_data['is_saleable'])

# %%
ch_data.columns
# Out:
# Index(['customer_profile_id', 'user_id', 'p_credit_score', 'p_occupation',
#        'p_equifax_income', 'p_customer_type', 'total_accounts',
#        'negative_status_accounts', 'positive_status_accounts', 'open_accounts',
#        'closed_accounts', 'max_dpd', 'credit_utilization', 'enquiries_made',
#        'seasoning', 'portfolio_mix_secured', 'portfolio_mix_unsecured',
#        'related_accounts', 'annual_income', 'calculated_emi', 'minor_issues',
#        'ontime_payment_percentage', 'no_of_delayed_payments',
#        'no_of_delayed_payments_on_active_accounts', 'no_of_active_accounts',
#        'existing_foir', 'credit_utilization_avg', 'is_saleable', 'sub',
#        'profile_validity'],
#       dtype='object')

# %%
ch_data.annual_income.median()
# Out:
# 30000.0

# %%
ch_data.shape
# Out:
# (82064, 30)

# %%
fig = plt.figure(figsize = (30,40))
ax = fig.gca()
ch_data.hist(ax = ax)
pyplot.show()
# Out:
# C:\Users\Pon kebha.DESKTOP-PI8M9QL\AppData\Local\Temp\ipykernel_15464\3830776909.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   ch_data.hist(ax = ax)

# %%
ch_data.isnull().sum()
# Out:
# customer_profile_id                              0
# user_id                                          0
# p_credit_score                                   0
# p_occupation                                 68364
# p_equifax_income                             37393
# p_customer_type                                  0
# total_accounts                                   0
# negative_status_accounts                         0
# positive_status_accounts                         0
# open_accounts                                    0
# closed_accounts                                  0
# max_dpd                                          0
# credit_utilization                               0
# enquiries_made                                   0
# seasoning                                        0
# portfolio_mix_secured                            0
# portfolio_mix_unsecured                          0
# related_accounts                                 0
# annual_income                                    0
# calculated_emi                                   0
# minor_issues                                     0
# ontime_payment_percentage                        0
# no_of_delayed_payments                           0
# no_of_delayed_payments_on_active_accounts        0
# no_of_active_accounts                            0
# existing_foir                                    0
# credit_utilization_avg                           0
# is_saleable                                      0
# sub                                              0
# profile_validity                                 0
# dtype: int64

# %%
''' get_occupation '''
def get_occupation(occupation):
    try:
        if occupation == 9:
            return 'Student'
        elif occupation in [1,2]:
            return 'Salaried'
        elif occupation in [3,4,5,6,7,8]:
            return 'SelfEmployed'
        elif occupation in [10,11]:
            return 'Other'
        else:
            return 'Other'
    except:
        return 'Other'
ch_data['p_occupation'] = ch_data['p_occupation'].apply(lambda x: get_occupation(x))
ch_data['p_occupation'].value_counts()
# Out:
# Other           68364
# Salaried         9016
# SelfEmployed     4684
# Name: p_occupation, dtype: int64

# %%
''' get_salary '''
def get_salary(salary):
    try:
        if salary == 1:
            return '<10k'
        elif salary == 2:
            return '10-15k'
        elif salary == 3:
            return '15-20k'
        elif salary == 4:
            return '20-25k'
        elif salary == 5:
            return '25-30k'
        elif salary == 6:
            return '30-35k'
        elif salary == 7:
            return '35-40k'
        elif salary == 8:
            return '40-45k'
        elif salary == 9:
            return '40-45k'
        elif salary == 10:
            return '40-45k'
        elif salary == 11:
            return '40-45k'
        elif salary == 12:
            return '40-45k'
        elif salary == 13:
            return '40-45k'
        elif salary ==14:
            return '40-45k'
        elif salary == 15:
            return '40-45k'
        else:
            return 'Other'
    except:
        return 'Other'
ch_data['p_equifax_income'] = ch_data['p_equifax_income'].apply(lambda x: get_salary(x))
ch_data['p_equifax_income'].value_counts()
# Out:
# Other     37393
# 40-45k    18334
# 15-20k     6927
# 10-15k     5234
# 20-25k     4851
# 25-30k     3293
# <10k       2607
# 30-35k     1902
# 35-40k     1523
# Name: p_equifax_income, dtype: int64

# %%
''' get_p_customer_type '''
def get_p_customer_type(type):
    try:
        if type == 1:
            return 'Green'
        elif type == 2:
            return 'Red'
        else:
            return 'Amber'
    except:
        return 'Amber'
ch_data['p_customer_type'] = ch_data['p_customer_type'].apply(lambda x: get_p_customer_type(x))
ch_data['p_customer_type'].value_counts()
# Out:
# Green    45844
# Red      29459
# Amber     6761
# Name: p_customer_type, dtype: int64

# %%
joblib.dump(ch_data, 'ch_clean_data_txn.pkl')
# Out:
# ['ch_clean_data_txn.pkl']

# %%
ch_data.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\style.py:3555: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\style.py:3556: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_faf42_row0_col0, #T_faf42_row1_col1, #T_faf42_row2_col2, #T_faf42_row3_col3, #T_faf42_row4_col4, #T_faf42_row5_col5, #T_faf42_row6_col6, #T_faf42_row7_col7, #T_faf42_row8_col8, #T_faf42_row9_col9, #T_faf42_row10_col10, #T_faf42_row11_col11, #T_faf42_row12_col12, #T_faf42_row13_col13, #T_faf42_row14_col14, #T_faf42_row15_col15, #T_faf42_row16_col16, #T_faf42_row17_col17, #T_faf42_row18_col18, #T_faf42_row19_col19, #T_faf42_row19_col20, #T_faf42_row20_col19, #T_faf42_row20_col20, #T_faf42_row21_col21, #T_faf42_row22_col22, #T_faf42_row23_col23, #T_faf42_row24_col24, #T_faf42_row25_col25 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_faf42_row0_
col2 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_faf42_row1_col21, #T_faf42_row11_col19, #T_faf42_row11_col20 {
#   background-color: #4a63d3;
#   color:

# %%
exclude=['profile_validity']

# %%
numerical_columns=list(ch_data.select_dtypes(include='number').columns)
for feature in numerical_columns:
    if feature in exclude:
        pass
    else:
        numerical_columns.remove(feature)
print(numerical_columns)
# Out:
# ['user_id', 'total_accounts', 'positive_status_accounts', 'closed_accounts', 'credit_utilization', 'seasoning', 'portfolio_mix_unsecured', 'annual_income', 'minor_issues', 'no_of_delayed_payments', 'no_of_active_accounts', 'credit_utilization_avg', 'sub', 'profile_validity']

# %%
skewed=[]
def find_skew(data,numerical_columns):
    skew_list={}
    for feature in numerical_columns:
        try:
            try:
                skew_value=(3*(data[feature].mean()-data[feature].median()))/data[feature].std()
                if ((round(skew_value,2)<-3) or (round(skew_value,2)>3)):
                    skew_list[feature]='Skewwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww'
                    skewed.append(feature)
                else:
                    skew_list[feature]=round(skew_value,2)
            except ZeroDivisionError:
                skew_list[feature]='Skewwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww'
                skewed.append(feature)
        except:
            pass
    return skew_list
skew_list=find_skew(ch_data,numerical_columns)
skew_list
# Out:
# {'user_id': -0.65,
#  'total_accounts': 1.05,
#  'positive_status_accounts': 0.33,
#  'closed_accounts': 0.79,
#  'credit_utilization': 1.7,
#  'seasoning': 0.84,
#  'portfolio_mix_unsecured': -1.99,
#  'annual_income': 1.1,
#  'minor_issues': 0.77,
#  'no_of_delayed_payments': 1.61,
#  'no_of_active_accounts': 1.05,
#  'credit_utilization_avg': 1.78,
#  'sub': 0.0,
#  'profile_validity': 'Skewwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww'}

# %%
for i in numerical_columns:
    if i in exclude:
        pass
    else:
        try:
            ch_data[i] =stats.boxcox(array)
        except:
            pass
find_skew(ch_data,numerical_columns)
# Out:
# {'user_id': -0.65,
#  'total_accounts': 1.05,
#  'positive_status_accounts': 0.33,
#  'closed_accounts': 0.79,
#  'credit_utilization': 1.7,
#  'seasoning': 0.84,
#  'portfolio_mix_unsecured': -1.99,
#  'annual_income': 1.1,
#  'minor_issues': 0.77,
#  'no_of_delayed_payments': 1.61,
#  'no_of_active_accounts': 1.05,
#  'credit_utilization_avg': 1.78,
#  'sub': 0.0,
#  'profile_validity': 'Skewwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww'}

# %%
joblib.dump(ch_data, 'ch_transformed_data_txn.pkl')
# Out:
# ['ch_transformed_data_txn.pkl']

# %%
user_ids=pd.concat([ch_data['user_id'].reset_index(drop = True)], axis = 1)
ch_data.drop(['user_id'],axis=1,inplace=True)

# %%
customer_profile_id=pd.concat([ch_data['customer_profile_id'].reset_index(drop = True)], axis = 1)
ch_data.drop(['customer_profile_id'],axis=1,inplace=True)

# %%
categorical_features=list(ch_data.select_dtypes(exclude='number').columns)
categorical_features
# Out:
# ['p_occupation', 'p_equifax_income', 'p_customer_type']

# %%
exemption_features=['sub']

# %%
numeric_features=list(ch_data.select_dtypes(include='number').columns)
numeric_features
flag_features=[]
for feature in exemption_features:
    numeric_features.remove(feature)
for feature in exclude:
    if feature in numeric_features:
        flag_features.append(feature)
        numeric_features.remove(feature)

# %%
id_columns=['user_id','customer_profile_id']
exemption_features=['sub']

# %%
dummies = pd.get_dummies(data = ch_data[categorical_features], drop_first=False)
dummies.columns
# Out:
# Index(['p_occupation_Other', 'p_occupation_Salaried',
#        'p_occupation_SelfEmployed', 'p_equifax_income_10-15k',
#        'p_equifax_income_15-20k', 'p_equifax_income_20-25k',
#        'p_equifax_income_25-30k', 'p_equifax_income_30-35k',
#        'p_equifax_income_35-40k', 'p_equifax_income_40-45k',
#        'p_equifax_income_<10k', 'p_equifax_income_Other',
#        'p_customer_type_Amber', 'p_customer_type_Green',
#        'p_customer_type_Red'],
#       dtype='object')

# %%
'''Scaling numeric features'''
standard_scalar = StandardScaler(with_mean=True,with_std=True)
standard_scalar.fit(ch_data[numeric_features])
numeric_data_scaled = standard_scalar.transform(ch_data[numeric_features])
numeric_data_scaled = pd.DataFrame(numeric_data_scaled,columns=numeric_features)
numeric_data_scaled.head()
# Out:
#    p_credit_score  total_accounts  negative_status_accounts  \
# 0            0.73           -0.49                     -0.69
# 1            0.48           -0.07                     -0.69
# 2            0.48            0.21                     -0.69
# 3            0.60           -0.63                     -0.69
# 4            0.73           -0.14                     -0.69
#
#    positive_status_accounts  open_accounts  closed_accounts  max_dpd  \
# 0                     -0.35           0.52            -1.04    -0.19
# 1                      0.36           0.07             0.20    -0.19
# 2                      0.84           1.42            -0.11    -0.19
# 3                     -0.58          -0.16            -0.88    -0.19
# 4                      0.25           0.52            -0.26    -0.19
#
#    credit_utilization  enquiries_made  seasoning  portfolio_mix_secured  \
# 0               -0.52            0.08       0.45                   0.31
# 1                1.30            1.22       0.09                   1.92
# 2                2.28            0.84       1.92                  -0.17
# 3               -0.57           -0.69       0.09                  -0.50
# 4               -0.57            2.75       1.55                  -0.01
#
#    portfolio_mix_unsecured  related_accounts  annual_income  calculated_emi  \
# 0                     0.27              0.24           3.19           -0.07
# 1                    -0.70              1.03          -0.46           -0.16
# 2                     0.57             -0.55          -0.45           -0.28
# 3                     0.76             -0.55          -0.37           -0.65
# 4                     0.47              0.24          -0.37           -0.19
#
#    minor_issues  ontime_payment_percentage  no_of_delayed_payments  \
# 0          0.78                       0.64                   -0.37
# 1         -0.26                       0.60                   -0.29
# 2         -0.78                       0.69                   -0.54
# 3         -0.78                       0.69                   -0.54
# 4         -0.78                       0.69                   -0.54
#
#    no_of_delayed_payments_on_active_accounts  no_of_active_accounts  \
# 0                                      -0.37                   0.24
# 1                                      -0.29                   0.24
# 2                                      -0.54                   1.73
# 3                                      -0.54                   0.24
# 4                                      -0.54                   1.13
#
#    existing_foir  credit_utilization_avg  is_saleable
# 0          -0.50                   -0.47        -0.47
# 1           0.75                    1.38        -0.47
# 2           0.40                    1.66        -0.47
# 3          -0.50                   -0.59        -0.47
# 4          -0.50                   -0.59        -0.47

# %%
'''Concatenating all features'''
processed_dataset = pd.concat([user_ids['user_id'].reset_index(drop = True), 
                               customer_profile_id['customer_profile_id'].reset_index(drop = True), 
                               numeric_data_scaled.reset_index(drop = True),
                               ch_data[flag_features].reset_index(drop = True),
                               dummies.reset_index(drop = True),
                              ch_data[exemption_features].reset_index(drop = True)
                              ], axis=1)
processed_dataset.shape
# Out:
# (82064, 42)

# %%
joblib.dump(processed_dataset, 'ch_processed_data_txn.pkl')
# Out:
# ['ch_processed_data_txn.pkl']

# %%
processed_dataset.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\style.py:
{
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_9f6de_row0_col17, #T_9f6de_row0_col23, #T_9f6de_row0_col41, #T_9f6de_row10_col0, #T_9f6de_row31_col30 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_9f6de_row0_col18, #T_9f6de_row8_col26, #T_9f6de_row9_col8, #T_9f6de_row10_col4, #T_9f6de_row10_col28, #T_9f6de_row29_col28, #T_9f6de_row30_col16, #T_9f6de_row30_col33, #T_9f6de_row31_col12, #T_9f6de_row31_col16, #T_9f6de_row31_col39, #T_9f6de_row32_col14, #T_9f6de_row32_col18, #T_9f6de_row32_col23, #T_9f6de_row32_col24, #T_9f6de_row32_col28, #T_9f6de_row33_col10, #T_9f6de_row33_col11, #T_9f6de_row36_col5, #T_9f6de_row36_col7, #T_9f6de_row37_col29 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_9f6de_row0_col19, #T_9f6de_row0_col20, #T_9f6de_row15_col38, #T_9f6de_row23_col29, #T_9f6de_row29_col1, #T_9f6de_row30_col32, #T_9f6de_row33_col17, #T_9f6de_row36_col14, #T_9f6de_row36_col21, #T_9f6de_row39_col24 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_9f6de_row0_col21, #T_9f6de_row33_col35 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_9f6de_row0_col22, #T_9f6de_row1_col26, #T_9f6de_row16_col26, #T_9f6de_row23_col12, #T_9f6de_row29_col9, #T_9f6de_row29_col33, #T_9f6de_row29_col34, #T_9f6de_row31_col0, #T_9f6de_row32_col8, #T_9f6de_row33_col16, #T_9f6de_row33_col23, #T_9f6de_row34_col11, #T_9f6de_row36_col17, #T_9f6de_row36_col18 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_9f6de_row0_col24, #T_9f6de_row8_col11, #T_9f6de_row8_col38, #T_9f6de_row14_col26, #T_9f6de_row18_col24, #T_9f6de_row18_col37, #T_9f6de_row26_col28, #T_9f6de_row31_col38, #T_9f6de_row32_col26, #T_9f6de_row32_col33, #T_9f6de_row34_col24, #T_9f6de_row34_col27, #T_9f6de_row34_col28, #T_9f6de_row36_col26, #T_9f6de_row37_col11, #T_9f6de_row41_col4 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_9f6de_row0_col25, #T_9f6de_row1_col25, #T_9f6de_row2_col25, #T_9f6de_row3_col25, #T_9f6de_row4_col25, #T_9f6de_row5_col25, #T_9f6de_row6_col25, #T_9f6de_row7_col25, #T_9f6de_row8_col25, #T_9f6de_row9_col25, #T_9f6de_row10_col25, #T_9f6de_row11_col25, #T_9f6de_row12_col25, #T_9f6de_row13_col25, #T_9f6de_row14_col25, #T_9f6de_row15_col25, #T_9f6de_row16_col25, #T_9f6de_row17_col25, #T_9f6de_row18_col25, #T_9f6de_row19_col25, #T_9f6de_row20_col25, #T_9f6de_row21_col25, #T_9f6de_row22_col25, #T_9f6de_row23_col25, #T_9f6de_row24_col25, #T_9f6de_row25_col0, #T_9f6de_row25_col1, #T_9f6de_row25_col2, #T_9f6de_row25_col3, #T_9f6de_row25_col4, #T_9f6de_row

# %%
ch_data.describe(percentiles=[0.01,0.05,0.10,0.25,0.5,0.75,0.9,0.95,0.99],datetime_is_numeric=True).transpose()
# Out:
#                                              count     mean       std  min  \
# p_credit_score                            82064.00   628.11    201.74 0.00
# total_accounts                            82064.00    16.00     14.25 0.00
# negative_status_accounts                  82064.00     0.54      0.79 0.00
# positive_status_accounts                  82064.00    11.93      8.44 0.00
# open_accounts                             82064.00     5.71      4.44 0.00
# closed_accounts                           82064.00     7.70      6.45 0.00
# max_dpd                                   82064.00     3.82     19.62 0.00
# credit_utilization                        82064.00    19.06     33.54 0.00
# enquiries_made                            82064.00     1.80      2.62 0.00
# seasoning                                 82064.00     2.76      2.73 0.00
# portfolio_mix_secured                     82064.00     0.12      0.25 0.00
# portfolio_mix_unsecured                   82064.00     0.69      0.41 0.00
# related_accounts                          82064.00     0.70      1.26 0.00
# annual_income                             82064.00 84463.80 149090.40 1.00
# calculated_emi                            82064.00 18524.00  23676.53 0.00
# minor_issues                              82064.00     1.49      1.92 0.00
# ontime_payment_percentage                 82064.00    74.10     37.54 0.00
# no_of_delayed_payments                    82064.00     6.51     12.15 0.00
# no_of_delayed_payments_on_active_accounts 82064.00     6.51     12.15 0.00
# no_of_active_accounts                     82064.00     4.18      3.37 0.00
# existing_foir                             82064.00   445.06    882.73 0.00
# credit_utilization_avg                    82064.00    18.97     31.93 0.00
# is_saleable                               82064.00     0.43      0.90 0.00
# sub                                       82064.00     0.50      0.50 0.00
# profile_validity                          82064.00     1.00      0.00 1.00
#
#                                               1%       5%      10%      25%  \
# p_credit_score                              0.00     0.00   525.00   625.00
# total_accounts                              0.00     0.00     1.00     5.00
# negative_status_accounts                    0.00     0.00     0.00     0.00
# positive_status_accounts                    0.00     0.00     1.00     4.00
# open_accounts                               0.00     0.00     1.00     2.00
# closed_accounts                             0.00     0.00     0.00     2.00
# max_dpd                                     0.00     0.00     0.00     0.00
# credit_utilization                          0.00     0.00     0.00     0.00
# enquiries_made                              0.00     0.00     0.00     0.00
# seasoning                                   0.00     0.00     0.00     0.00
# portfolio_mix_secured                       0.00     0.00     0.00     0.00
# portfolio_mix_unsecured                     0.00     0.00     0.00     0.33
# related_accounts                            0.00     0.00     0.00     0.00
# annual_income                             500.00 13000.00 16000.00 28000.00
# calculated_emi                              0.00     0.00     0.00  1274.35
# minor_issues                                0.00     0.00     0.00     0.00
# ontime_payment_percentage                   0.00     0.00     0.00    55.80
# no_of_delayed_payments                      0.00     0.00     0.00     0.00
# no_of_delayed_payments_on_active_accounts   0.00     0.00     0.00     0.00
# no_of_active_accounts                       0.00     0.00     0.00     1.00
# existing_foir                               0.00     0.00     0.00     0.00
# credit_utilization_avg                      0.00     0.00     0.00     0.00
# is_saleable                                 0.00     0.00     0.00     0.00
# sub                                         0.00     0.00     0.00     0.00
# profile_validity                            1.00     1.00     1.00     1.00
#
#                                                50%      75%       90%  \
# p_credit_score                              700.00   725.00    775.00
# total_accounts                               11.00    24.00     42.00
# negative_status_accounts                      0.00     1.00      2.00
# positive_status_accounts                     11.00    23.00     23.00
# open_accounts                                 5.00     9.00     14.00
# closed_accounts                               6.00    15.00     17.00
# max_dpd                                       0.00     0.00      0.00
# credit_utilization                            0.00    26.13     86.19
# enquiries_made                                1.00     3.00      5.00
# seasoning                                     2.00     5.00      8.00
# portfolio_mix_secured                         0.00     0.14      0.50
# portfolio_mix_unsecured                       0.96     1.00      1.00
# related_accounts                              0.00     1.00      2.00
# annual_income                             30000.00 35000.00 300001.00
# calculated_emi                             7746.18 25856.51  68124.97
# minor_issues                                  1.00     2.00      4.00
# ontime_payment_percentage                    97.84   100.00    100.00
# no_of_delayed_payments                        0.00     6.00     23.00
# no_of_delayed_payments_on_active_accounts     0.00     6.00     23.00
# no_of_active_accounts                         3.00     7.00     10.00
# existing_foir                                 0.10   433.07   1520.64
# credit_utilization_avg                        0.00    30.00     79.00
# is_saleable                                   0.00     0.00      2.00
# sub                                           0.50     1.00      1.00
# profile_validity                              1.00     1.00      1.00
#
#                                                 95%       99%       max
# p_credit_score                               775.00    775.00    775.00
# total_accounts                                47.00     47.00     47.00
# negative_status_accounts                       2.00      2.00      2.00
# positive_status_accounts                      23.00     23.00     23.00
# open_accounts                                 14.00     14.00     14.00
# closed_accounts                               17.00     17.00     17.00
# max_dpd                                        0.00    120.00    120.00
# credit_utilization                            99.12    100.00    100.00
# enquiries_made                                 7.00     13.00     13.00
# seasoning                                      8.00      8.00      8.00
# portfolio_mix_secured                          0.75      1.00      1.00
# portfolio_mix_unsecured                        1.00      1.00      1.00
# related_accounts                               4.00      5.00      5.00
# annual_income                             560000.00 560000.00 560000.00
# calculated_emi                             75000.00  75000.00  75000.00
# minor_issues                                   5.00      9.00     10.00
# ontime_payment_percentage                    100.00    100.00    100.00
# no_of_delayed_payments                        42.00     45.00     45.00
# no_of_delayed_payments_on_active_accounts     42.00     45.00     45.00
# no_of_active_accounts                         10.00     10.00     10.00
# existing_foir                               3171.43   3500.00   3500.00
# credit_utilization_avg                        98.00    100.00    100.00
# is_saleable                                    2.00      4.00      4.00
# sub                                            1.00      1.00      1.00
# profile_validity                               1.00      1.00      1.00

# %%
'''Replace Infinite'''
processed_dataset = processed_dataset.replace([np.inf, -np.inf], np.nan).dropna(axis=0)
processed_dataset.shape
# Out:
# (82064, 42)

# %%
data=processed_dataset[[
'max_dpd',
 'p_customer_type_Amber',
 'p_occupation_Salaried',
 'p_occupation_Other',
 'p_occupation_SelfEmployed',
 'p_equifax_income_40-45k',
 'p_equifax_income_Other',
 'related_accounts',
 'minor_issues',
 'annual_income',
 'closed_accounts',
 'is_saleable',
 'existing_foir',
 'portfolio_mix_secured',
 'positive_status_accounts',
 'total_accounts',
 'p_customer_type_Red',
 'calculated_emi',
 'negative_status_accounts',
 'portfolio_mix_unsecured',
 'open_accounts',
 'enquiries_made',
 'no_of_delayed_payments',
 'no_of_active_accounts',
 'p_customer_type_Green',
 'p_credit_score',
 'no_of_delayed_payments_on_active_accounts',
 'credit_utilization',
 'credit_utilization_avg',
 'seasoning',
 'ontime_payment_percentage']]

# %%
'''  Splitting test and train data '''
data=processed_dataset.drop(['customer_profile_id','profile_validity'],axis=1)

X = data.loc[:,data.columns != 'sub']
y = data['sub']
train_X_u,test_X_u,train_y,test_y = train_test_split(X,y,random_state=13,test_size=0.1)
train_X = train_X_u.loc[:,train_X_u.columns != 'user_id']
test_X = test_X_u.loc[:,test_X_u.columns != 'user_id']

# %%
train_X.head()
# Out:
#        p_credit_score  total_accounts  negative_status_accounts  \
# 21777            0.60            0.35                     -0.69
# 31515            0.60            2.18                     -0.69
# 3041             0.48            0.14                     -0.69
# 60526            0.11            0.28                      0.58
# 66779           -0.14           -0.21                      1.85
#
#        positive_status_accounts  open_accounts  closed_accounts  max_dpd  \
# 21777                      1.07           0.29             0.98    -0.19
# 31515                      1.31           1.87             1.44    -0.19
# 3041                       0.72           1.19            -0.11    -0.19
# 60526                      0.84           0.07             0.98     4.39
# 66779                     -0.11          -0.39             0.20    -0.19
#
#        credit_utilization  enquiries_made  seasoning  portfolio_mix_secured  \
# 21777               -0.57           -0.30       0.09                  -0.50
# 31515                1.28            3.13       1.92                  -0.50
# 3041                 0.08           -0.69       1.92                  -0.13
# 60526               -0.57           -0.69       0.09                  -0.50
# 66779                2.41           -0.69      -1.01                  -0.50
#
#        portfolio_mix_unsecured  related_accounts  annual_income  \
# 21777                     0.76              3.40           3.19
# 31515                     0.76             -0.55          -0.33
# 3041                      0.54             -0.55          -0.45
# 60526                     0.76             -0.55          -0.40
# 66779                    -1.67             -0.55          -0.26
#
#        calculated_emi  minor_issues  ontime_payment_percentage  \
# 21777            2.39         -0.26                       0.69
# 31515            2.39          0.78                       0.69
# 3041             0.68         -0.78                       0.69
# 60526           -0.11          0.78                       0.69
# 66779           -0.54          0.26                      -1.22
#
#        no_of_delayed_payments  no_of_delayed_payments_on_active_accounts  \
# 21777                   -0.54                                      -0.54
# 31515                   -0.54                                      -0.54
# 3041                    -0.54                                      -0.54
# 60526                   -0.54                                      -0.54
# 66779                    1.60                                       1.60
#
#        no_of_active_accounts  existing_foir  credit_utilization_avg  \
# 21777                   0.54          -0.50                   -0.59
# 31515                   1.73           3.46                    0.91
# 3041                    1.73           2.26                    0.09
# 60526                  -0.35           0.36                   -0.59
# 66779                  -0.65          -0.33                    2.54
#
#        is_saleable  p_occupation_Other  p_occupation_Salaried  \
# 21777        -0.47                   1                      0
# 31515        -0.47                   1                      0
# 3041         -0.47                   1                      0
# 60526        -0.47                   1                      0
# 66779         1.75                   1                      0
#
#        p_occupation_SelfEmployed  p_equifax_income_10-15k  \
# 21777                          0                        0
# 31515                          0                        0
# 3041                           0                        0
# 60526                          0                        0
# 66779                          0                        0
#
#        p_equifax_income_15-20k  p_equifax_income_20-25k  \
# 21777                        0                        0
# 31515                        0                        0
# 3041                         1                        0
# 60526                        0                        1
# 66779                        0                        0
#
#        p_equifax_income_25-30k  p_equifax_income_30-35k  \
# 21777                        0                        0
# 31515                        0                        0
# 3041                         0                        0
# 60526                        0                        0
# 66779                        0                        0
#
#        p_equifax_income_35-40k  p_equifax_income_40-45k  \
# 21777                        0                        1
# 31515                        1                        0
# 3041                         0                        0
# 60526                        0                        0
# 66779                        0                        1
#
#        p_equifax_income_<10k  p_equifax_income_Other  p_customer_type_Amber  \
# 21777                      0                       0                      0
# 31515                      0                       0                      0
# 3041                       0                       0                      0
# 60526                      0                       0                      0
# 66779                      0                       0                      0
#
#        p_customer_type_Green  p_customer_type_Red
# 21777                      1                    0
# 31515                      1                    0
# 3041                       1                    0
# 60526                      0                    1
# 66779                      0                    1

# %%
#RandomForest
''' Tuning Grid '''
gridParams = {
#                 'n_estimators': [100],
#                 'max_features':['sqrt'],
#                 'bootstrap': [True],
                'random_state' : [12],
#                 'warm_start':[False],
                'criterion':['gini', 'entropy'],
#                 'max_depth':[47],
                'min_samples_split':[0.00000002,0.00000003,0.00000004,0.00000005],
                'min_samples_leaf':[0.0000002,0.0000003,0.0000004,0.0000005]
             }

'''Model Object'''
model2 = RandomForestClassifier()

''' Grid Formation '''
grid = RandomizedSearchCV(estimator = model2 , param_distributions= gridParams, verbose = 2, cv = 3, n_iter=1000)
grid.fit(train_X, train_y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:292: UserWarning: The total space of parameters 32 is smaller than n_iter=1000. Running 32 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=2e-08, random_state=12; total time=   8.9s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=2e-08, random_state=12; total time=   8.4s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=2e-08, random_state=12; total time=   9.4s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=3e-08, random_state=12; total time=   8.4s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=3e-08, random_state=12; total time=   8.0s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15464\2673407898.py in <module>
#      18 ''' Grid Formation '''
#      19 grid = RandomizedSearchCV(estimator = model2 , param_distributions= gridParams, verbose = 2, cv = 3, n_iter=1000)
# ---> 20 grid.fit(train_X, train_y)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     889                 return results
#     890
# --> 891             self._run_search(evaluate_candidates)
#     892
#     893             # multimetric is determined here because in the case of a callable
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1764     def _run_search(self, evaluate_candidates):
#    1765         """Search n_iter candidates from param_distributions"""
# -> 1766         evaluate_candidates(
#    1767             ParameterSampler(
#    1768                 self.param_distributions, self.n_iter, random_state=self.random_state
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     836                     )
#     837
# --> 838                 out = parallel(
#     839                     delayed(_fit_and_score)(
#     840                         clone(base_estimator),
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1049                 self._iterating = self._original_iterator is not None
#    1050
# -> 1051             while self.dispatch_one_batch(iterator):
#    1052                 pass
#    1053
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     862                 return False
#     863             else:
# --> 864                 self._dispatch(tasks)
#     865                 return True
#     866
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     780         with self._lock:
#     781             job_idx = len(self._jobs)
# --> 782             job = self._backend.apply_async(batch, callback=cb)
#     783             # A job can complete so quickly than its callback is
#     784             # called before we get here, causing self._jobs to
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     261         # change the default number of processes to -1
#     262         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263             return [func(*args, **kwargs)
#     264                     for func, args, kwargs in self.items]
#     265
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     261         # change the default number of processes to -1
#     262         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263             return [func(*args, **kwargs)
#     264                     for func, args, kwargs in self.items]
#     265
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     214     def __call__(self, *args, **kwargs):
#     215         with config_context(**self.config):
# --> 216             return self.function(*args, **kwargs)
#     217
#     218
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     678             estimator.fit(X_train, **fit_params)
#     679         else:
# --> 680             estimator.fit(X_train, y_train, **fit_params)
#     681
#     682     except Exception:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     448             # parallel_backend contexts set at a higher level,
#     449             # since correctness does not rely on using threads.
# --> 450             trees = Parallel(
#     451                 n_jobs=self.n_jobs,
#     452                 verbose=self.verbose,
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1049                 self._iterating = self._original_iterator is not None
#    1050
# -> 1051             while self.dispatch_one_batch(iterator):
#    1052                 pass
#    1053
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     862                 return False
#     863             else:
# --> 864                 self._dispatch(tasks)
#     865                 return True
#     866
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     780         with self._lock:
#     781             job_idx = len(self._jobs)
# --> 782             job = self._backend.apply_async(batch, callback=cb)
#     783             # A job can complete so quickly than its callback is
#     784             # called before we get here, causing self._jobs to
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     261         # change the default number of processes to -1
#     262         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263             return [func(*args, **kwargs)
#     264                     for func, args, kwargs in self.items]
#     265
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     261         # change the default number of processes to -1
#     262         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263             return [func(*args, **kwargs)
#     264                     for func, args, kwargs in self.items]
#     265
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     214     def __call__(self, *args, **kwargs):
#     215         with config_context(**self.config):
# --> 216             return self.function(*args, **kwargs)
#     217
#     218
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     183             curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
#     184
# --> 185         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     186     else:
#     187         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     935         """
#     936
# --> 937         super().fit(
#     938             X,
#     939             y,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     418             )
#     419
# --> 420         builder.build(self.tree_, X, y, sample_weight)
#     421
#     422         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
#RandomForest

'''Model Object'''
model = RandomForestClassifier(criterion='entropy', min_samples_split=0.00005,  random_state=15)
model.fit(train_X, train_y)
# Out:
# RandomForestClassifier(criterion='entropy', min_samples_split=5e-05,
#                        random_state=15)

# %%
dict(sorted(dict(zip(grid.feature_names_in_, model.feature_importances_)).items(), key=lambda item: item[1]))

# %%
dict(sorted(dict(zip(model.feature_names_in_, model.feature_importances_)).items(), key=lambda item: item[1]))
# Out:
# {'p_customer_type_Amber': 0.001511825213459967,
#  'p_equifax_income_35-40k': 0.0020265500560519146,
#  'p_equifax_income_<10k': 0.0022655820031483075,
#  'p_equifax_income_30-35k': 0.0025158676525866754,
#  'max_dpd': 0.0037680670477794964,
#  'p_equifax_income_25-30k': 0.0039735630784163995,
#  'p_equifax_income_10-15k': 0.0042230467770728725,
#  'p_equifax_income_20-25k': 0.004545264702625571,
#  'p_customer_type_Red': 0.0045738673282002765,
#  'p_customer_type_Green': 0.004617452127689119,
#  'p_equifax_income_15-20k': 0.005310334057984838,
#  'p_occupation_SelfEmployed': 0.0054134716402199105,
#  'p_equifax_income_40-45k': 0.006018843587849449,
#  'p_equifax_income_Other': 0.007014588817657038,
#  'p_occupation_Salaried': 0.007591924363740514,
#  'negative_status_accounts': 0.0083217068594093,
#  'p_occupation_Other': 0.009031196690127384,
#  'is_saleable': 0.013990198347201359,
#  'portfolio_mix_secured': 0.018826673243043747,
#  'related_accounts': 0.02384325060028051,
#  'no_of_delayed_payments': 0.026599886555473004,
#  'no_of_delayed_payments_on_active_accounts': 0.026655203119374395,
#  'open_accounts': 0.03650378812050206,
#  'portfolio_mix_unsecured': 0.03699259771424453,
#  'closed_accounts': 0.038292788414666296,
#  'annual_income': 0.04136022949529331,
#  'positive_status_accounts': 0.04155210812682683,
#  'minor_issues': 0.04227399860924104,
#  'existing_foir': 0.04390465830139937,
#  'enquiries_made': 0.04601888382768395,
#  'credit_utilization_avg': 0.04608647281396014,
#  'credit_utilization': 0.04719748074012855,
#  'no_of_active_accounts': 0.04772964149874908,
#  'total_accounts': 0.05051077613246399,
#  'p_credit_score': 0.05222560608477772,
#  'seasoning': 0.057036445364602395,
#  'ontime_payment_percentage': 0.06534227287739154,
#  'calculated_emi': 0.11433388800867712}

# %%
joblib.dump(grid,"CH_TXN_RF_v1.pkl")

# %%
joblib.dump(model,"CH_TXN_RF_v1.1.pkl")
# Out:
# ['CH_TXN_RF_v1.1.pkl']

# %%
grid.best_estimator_

# %%
test_fit2 = grid.predict(test_X)
y_pred=pd.DataFrame(test_fit2)

# %%
test_fit1 = model.predict(test_X)
y_pred1=pd.DataFrame(test_fit1)

# %%
test_fit3 = model.predict(train_X)
y_pred3=pd.DataFrame(test_fit3)

# %%
accuracy_score(test_y, y_pred)

# %%
accuracy_score(test_y, y_pred1)
# Out:
# 0.7396125258925308

# %%
accuracy_score(train_y, y_pred3)
# Out:
# 0.9749651353290819

# %%
cm=ConfusionMatrixDisplay(confusion_matrix(test_y, y_pred))
cm.plot()
plt.show()

# %%
cm=ConfusionMatrixDisplay(confusion_matrix(test_y, y_pred1))
cm.plot()
plt.show()

# %%
cm=ConfusionMatrixDisplay(confusion_matrix(train_y, y_pred3))
cm.plot()
plt.show()

# %%
false_positive_rate, true_positive_rate, threshold1 = roc_curve(test_y, y_pred)
'roc='+str(roc_auc_score(test_y, y_pred))

# %%
false_positive_rate2, true_positive_rate2, threshold2 = roc_curve(test_y, y_pred1)
'roc='+str(roc_auc_score(test_y, y_pred1))
# Out:
# 'roc=0.7443783071139697'

# %%
false_positive_rate3, true_positive_rate3, threshold3 = roc_curve(train_y, y_pred3)
'roc='+str(roc_auc_score(train_y, y_pred3))
# Out:
# 'roc=0.8186749722687474'

# %%
mae = mean_absolute_error(test_y, y_pred)
mse = mean_squared_error(test_y, y_pred)
rmse = np.sqrt(mse) # or mse**(0.5)  
r2 = r2_score(test_y, y_pred)

print("Results of sklearn.metrics:")
print("MAE:",mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R-Squared:", r2)

# %%
mae = mean_absolute_error(test_y, y_pred1)
mse = mean_squared_error(test_y, y_pred1)
rmse = np.sqrt(mse) # or mse**(0.5)  
r2 = r2_score(test_y, y_pred1)

print("Results of sklearn.metrics:")
print("MAE:",mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R-Squared:", r2)
# Out:
# Results of sklearn.metrics:
# MAE: 0.2556354331668088
# MSE: 0.2556354331668088
# RMSE: 0.5056040280365741
# R-Squared: -0.022542476556978608

# %%
mae = mean_absolute_error(train_y, y_pred3)
mse = mean_squared_error(train_y, y_pred3)
rmse = np.sqrt(mse) # or mse**(0.5)  
r2 = r2_score(train_y, y_pred3)

print("Results of sklearn.metrics:")
print("MAE:",mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R-Squared:", r2)
# Out:
# Results of sklearn.metrics:
# MAE: 0.18132336813030586
# MSE: 0.18132336813030586
# RMSE: 0.4258208169292641
# R-Squared: 0.2747065209635948

# %%
plt.subplots(1, figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate, true_positive_rate)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
plt.subplots(1, figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate2, true_positive_rate2)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate 2')
plt.xlabel('False Positive Rate 2')
plt.show()

# %%
plt.subplots(1, figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate3, true_positive_rate3)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate 3')
plt.xlabel('False Positive Rate 3')
plt.show()
