# %% [markdown]
# # Credit Hungry for AL Products Model

# %%
'''Importing Required Libraries'''
import copy
from collections import OrderedDict
import pandas as pd
import lightgbm as lgb
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.options.display.float_format = '{:.2f}'.format
pd.options.mode.chained_assignment = None  # default='warn'
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import scatter_matrix
from matplotlib import pyplot
from scipy import stats
from scipy.stats import norm, skew
from sklearn.preprocessing import PowerTransformer, QuantileTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import LogisticRegression, SGDClassifier,SGDRegressor
from sklearn.ensemble import RandomForestClassifier,VotingClassifier
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import accuracy_score, roc_curve, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.pipeline import make_pipeline
import joblib
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# %%
'''Importing the data for modelling'''
ch_data = pd.read_csv(r"D:\Dbeaver Out\CH_AL_data_2207_matched_202303271342.csv", na_values=['',' ','NH', 'NA', '[]'], low_memory=False)

# %%
ch_data.drop(['status','report_source', 'report_id', 'report_date', 'filename_prefix', 'pan_no',
        'passport_no', 'driving_license_no', 'voter_id_no', 'ration_card_no',
        'uid_no', 'national_card_no', 'photo_credit_card_no', 'other_id_no',
        'account_type', 'reported_on', 'frequency', 'income_indicator',
        'ability_to_borrow_cc', 'ability_to_borrow_hl', 'ability_to_borrow_pl',
        'ability_to_borrow_al','created_on', 'modified_on', 'modified_by', 'modified_ts','is_active'],axis=1,inplace=True)

# %%
ch_data.annual_income = ch_data.annual_income.apply(lambda x: (x * -1) if x < 0 else x)
ch_data.drop(ch_data[ch_data['existing_foir'] < 0].index, inplace = True)

# %%
ch_data.total_accounts.fillna(0, inplace= True) 
ch_data.negative_status_accounts.fillna(0, inplace= True) 
ch_data.positive_status_accounts.fillna(0, inplace= True) 
ch_data.open_accounts.fillna(0, inplace= True) 
ch_data.closed_accounts.fillna(0, inplace= True) 
ch_data.max_dpd.fillna(0, inplace= True) 
ch_data.credit_utilization.fillna(0, inplace= True) 
ch_data.enquiries_made.fillna(0, inplace= True) 
ch_data.seasoning.fillna(0, inplace= True) 
ch_data.portfolio_mix_secured.fillna(0, inplace= True) 
ch_data.portfolio_mix_unsecured.fillna(0, inplace= True) 
ch_data.related_accounts.fillna(0, inplace= True) 
ch_data.annual_income.fillna(30000, inplace= True) 
ch_data.calculated_emi.fillna(0, inplace= True) 
ch_data.minor_issues.fillna(0, inplace= True) 
ch_data.ontime_payment_percentage.fillna(0, inplace= True) 
ch_data.no_of_delayed_payments.fillna(0, inplace= True) 
ch_data.no_of_delayed_payments_on_active_accounts.fillna(0, inplace= True) 
ch_data.no_of_active_accounts.fillna(0, inplace= True) 
ch_data.existing_foir.fillna(0, inplace= True) 
ch_data.credit_utilization_avg.fillna(0, inplace= True)

# %%
ch_data['p_credit_score'] = np.where(ch_data['p_credit_score']>775,775,ch_data['p_credit_score'])
ch_data['total_accounts'] = np.where(ch_data['total_accounts']>47,47,ch_data['total_accounts'])
ch_data['negative_status_accounts'] = np.where(ch_data['negative_status_accounts']>2,2,ch_data['negative_status_accounts'])
ch_data['positive_status_accounts'] = np.where(ch_data['positive_status_accounts']>23,23,ch_data['positive_status_accounts'])
ch_data['open_accounts'] = np.where(ch_data['open_accounts']>14,14,ch_data['open_accounts'])
ch_data['closed_accounts'] = np.where(ch_data['closed_accounts']>17,17,ch_data['closed_accounts'])
ch_data['max_dpd'] = np.where(ch_data['max_dpd']>120,120,ch_data['max_dpd'])
ch_data['credit_utilization'] = np.where(ch_data['credit_utilization']>100,100,ch_data['credit_utilization'])
ch_data['enquiries_made'] = np.where(ch_data['enquiries_made']>13,13,ch_data['enquiries_made'])
ch_data['seasoning'] = np.where(ch_data['seasoning']>8,8,ch_data['seasoning'])
ch_data['portfolio_mix_secured'] = np.where(ch_data['portfolio_mix_secured']>1,1,ch_data['portfolio_mix_secured'])
ch_data['portfolio_mix_unsecured'] = np.where(ch_data['portfolio_mix_unsecured']>1,1,ch_data['portfolio_mix_unsecured'])
ch_data['related_accounts'] = np.where(ch_data['related_accounts']>5,5,ch_data['related_accounts'])
ch_data['annual_income'] = np.where(ch_data['annual_income']>560000,560000,ch_data['annual_income'])
ch_data['calculated_emi'] = np.where(ch_data['calculated_emi']>75000,75000,ch_data['calculated_emi'])
ch_data['minor_issues'] = np.where(ch_data['minor_issues']>10,10,ch_data['minor_issues'])
ch_data['no_of_delayed_payments'] = np.where(ch_data['no_of_delayed_payments']>45,45,ch_data['no_of_delayed_payments'])
ch_data['no_of_delayed_payments_on_active_accounts'] = np.where(ch_data['no_of_delayed_payments_on_active_accounts']>45,45,ch_data['no_of_delayed_payments_on_active_accounts'])
ch_data['no_of_active_accounts'] = np.where(ch_data['no_of_active_accounts']>10,10,ch_data['no_of_active_accounts'])
ch_data['existing_foir'] = np.where(ch_data['existing_foir']>3500,3500,ch_data['existing_foir'])
ch_data['credit_utilization_avg'] = np.where(ch_data['credit_utilization_avg']>100,100,ch_data['credit_utilization_avg'])
ch_data['is_saleable'] = np.where(ch_data['is_saleable']>4,4,ch_data['is_saleable'])

# %%
ch_data.columns
# Out:
# Index(['customer_profile_id', 'user_id', 'p_credit_score', 'p_occupation',
#        'p_equifax_income', 'p_customer_type', 'total_accounts',
#        'negative_status_accounts', 'positive_status_accounts', 'open_accounts',
#        'closed_accounts', 'max_dpd', 'credit_utilization', 'enquiries_made',
#        'seasoning', 'portfolio_mix_secured', 'portfolio_mix_unsecured',
#        'related_accounts', 'annual_income', 'calculated_emi', 'minor_issues',
#        'ontime_payment_percentage', 'no_of_delayed_payments',
#        'no_of_delayed_payments_on_active_accounts', 'no_of_active_accounts',
#        'existing_foir', 'credit_utilization_avg', 'is_saleable', 'sub',
#        'profile_validity'],
#       dtype='object')

# %%
ch_data.annual_income.median()
# Out:
# 30000.0

# %%
ch_data.shape
# Out:
# (12542, 30)

# %%
fig = plt.figure(figsize = (30,40))
ax = fig.gca()
ch_data.hist(ax = ax)
pyplot.show()
# Out:
# C:\Users\Pon kebha.DESKTOP-PI8M9QL\AppData\Local\Temp\ipykernel_17944\3830776909.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   ch_data.hist(ax = ax)

# %%
ch_data.isnull().sum()
# Out:
# customer_profile_id                              0
# user_id                                          0
# p_credit_score                                   0
# p_occupation                                 10515
# p_equifax_income                              5877
# p_customer_type                                  0
# total_accounts                                   0
# negative_status_accounts                         0
# positive_status_accounts                         0
# open_accounts                                    0
# closed_accounts                                  0
# max_dpd                                          0
# credit_utilization                               0
# enquiries_made                                   0
# seasoning                                        0
# portfolio_mix_secured                            0
# portfolio_mix_unsecured                          0
# related_accounts                                 0
# annual_income                                    0
# calculated_emi                                   0
# minor_issues                                     0
# ontime_payment_percentage                        0
# no_of_delayed_payments                           0
# no_of_delayed_payments_on_active_accounts        0
# no_of_active_accounts                            0
# existing_foir                                    0
# credit_utilization_avg                           0
# is_saleable                                      0
# sub                                              0
# profile_validity                                 0
# dtype: int64

# %%
''' get_occupation '''
def get_occupation(occupation):
    try:
        if occupation == 9:
            return 'Student'
        elif occupation in [1,2]:
            return 'Salaried'
        elif occupation in [3,4,5,6,7,8]:
            return 'SelfEmployed'
        elif occupation in [10,11]:
            return 'Other'
        else:
            return 'Other'
    except:
        return 'Other'
ch_data['p_occupation'] = ch_data['p_occupation'].apply(lambda x: get_occupation(x))
ch_data['p_occupation'].value_counts()
# Out:
# Other           10515
# Salaried         1219
# SelfEmployed      808
# Name: p_occupation, dtype: int64

# %%
''' get_salary '''
def get_salary(salary):
    try:
        if salary == 1:
            return '<10k'
        elif salary == 2:
            return '10-15k'
        elif salary == 3:
            return '15-20k'
        elif salary == 4:
            return '20-25k'
        elif salary == 5:
            return '25-30k'
        elif salary == 6:
            return '30-35k'
        elif salary == 7:
            return '35-40k'
        elif salary == 8:
            return '40-45k'
        elif salary == 9:
            return '40-45k'
        elif salary == 10:
            return '40-45k'
        elif salary == 11:
            return '40-45k'
        elif salary == 12:
            return '40-45k'
        elif salary == 13:
            return '40-45k'
        elif salary ==14:
            return '40-45k'
        elif salary == 15:
            return '40-45k'
        else:
            return 'Other'
    except:
        return 'Other'
ch_data['p_equifax_income'] = ch_data['p_equifax_income'].apply(lambda x: get_salary(x))
ch_data['p_equifax_income'].value_counts()
# Out:
# Other     5877
# 40-45k    3086
# 15-20k     907
# 10-15k     707
# 20-25k     621
# 25-30k     449
# <10k       411
# 30-35k     254
# 35-40k     230
# Name: p_equifax_income, dtype: int64

# %%
''' get_p_customer_type '''
def get_p_customer_type(type):
    try:
        if type == 1:
            return 'Green'
        elif type == 2:
            return 'Red'
        else:
            return 'Amber'
    except:
        return 'Amber'
ch_data['p_customer_type'] = ch_data['p_customer_type'].apply(lambda x: get_p_customer_type(x))
ch_data['p_customer_type'].value_counts()
# Out:
# Green    6126
# Red      5382
# Amber    1034
# Name: p_customer_type, dtype: int64

# %%
joblib.dump(ch_data, 'ch_clean_data_AL.pkl')
# Out:
# ['ch_clean_data_AL.pkl']

# %%
ch_data.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\style.py:3555: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\style.py:3556: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_086a5_row0_col0, #T_086a5_row1_col1, #T_086a5_row2_col2, #T_086a5_row3_col3, #T_086a5_row4_col4, #T_086a5_row5_col5, #T_086a5_row6_col6, #T_086a5_row7_col7, #T_086a5_row8_col8, #T_086a5_row9_col9, #T_086a5_row10_col10, #T_086a5_row11_col11, #T_086a5_row12_col12, #T_086a5_row13_col13, #T_086a5_row14_col14, #T_086a5_row15_col15, #T_086a5_row16_col16, #T_086a5_row17_col17, #T_086a5_row18_col18, #T_086a5_row19_col19, #T_086a5_row19_col20, #T_086a5_row20_col19, #T_086a5_row20_col20, #T_086a5_row21_col21, #T_086a5_row22_col22, #T_086a5_row23_col23, #T_086a5_row24_col24, #T_086a5_row25_col25 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_086a5_row0_col1, #T_086a5_row1_col5, #T_086a5_row2_col1, #T_086a5_row3_col1, #T_086a5_row4_col1, #T_086a5_row5_col1, #T_086a5_row6_col1, #T_086a5_row7_col1, #T_086a5_row8_col18, #T_086a5_row9_col1, #T_086a5_row10_col1, #T_086a5_row11_col1, #T_086a5_row12_col13, #T_086a5_row13_col12, #T_086a5_row14_col1, #T_086a5_row15_col1, #T_086a5_row16_col1, #T_086a5_row17_col1, #T_086a5_row18_col19, #T_086a5_row18_col20, #T_086a5_row19_col18, #T_086a5_row20_col18, #T_086a5_row21_col1, #T_086a5_row22_col1, #T_086a5_row23_col1, #T_086a5_row24_col1, #T_086a5_row25_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_086a5_row0_col2, #T_086a5_row0_col10, #T_086a5_row2_col7, #T_086a5_row4_col14, #T_086a5_row5_col12, #T_086a5_row10_col5, #T_086a5_row12_col25, #T_086a5_row14_col18, #T_086a5_row15_col5, #T_086a5_row17_col4, #T_086a5_row17_col10, #T_086a5_row23_col15 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_086a5_row0_col3, #T_086a5_row0_col6, #T_086a5_row0_col7, #T_086a5_row14_col22, #T_086a5_row25_col6 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_086a5_row0_col4, #T_086a5_row9_col17, #T_086a5_row12_col0, #T_086a5_row14_col9, #T_086a5_row15_col23, #T_086a5_row22_col25 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_086a5_row0_col5, #T_086a5_row3_col0, #T_086a5_row6_col25, #T_086a5_row16_col18, #T_086a5_row25_col5 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_086a5_row0_col8, #T_086a5_row2_col9, #T_086a5_row2_col23, #T_086a5_row12_col23, #T_086a5_row15_col24, #T_086a5_row22_col2 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_086a5_row0_col9, #T_086a5_row4_col8, #T_086a5_row6_col24 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_086a5_row0_col11, #T_086a5_row3_col13 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_086a5_row0_col12, #T_086a5_row13_col14, #T_086a5_row14_col15, #T_086a5_row14_col23, #T_086a5_row18_col12, #T_086a5_row18_col22, #T_086a5_row18_col23, #T_086a5_row24_col6, #T_086a5_row25_col12 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_086a5_row0_col13, #T_086a5_row0_col23, #T_086a5_row13_col17, #T_086a5_row14_col4, #T_086a5_row17_col22, #T_086a5_row21_col24 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_086a5_row0_col14, #T_086a5_row3_col4, #T_086a5_row7_col23, #T_086a5_row9_col3 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_086a5_row0_col15, #T_086a5_row11_col14, #T_086a5_row19_col21, #T_086a5_row20_col21 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_086a5_row0_col16, #T_086a5_row21_col0 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_086a5_row0_col17, #T_086a5_row2_col17, #T_086a5_row4_col23, #T_086a5_row9_col24, #T_086a5_row10_col16, #T_086a5_row10_col18 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_086a5_row0_col18, #T_086a5_row3_col24, #T_086a5_row13_col16, #T_086a5_row18_col3 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_086a5_row0_col19, #T_086a5_row0_col20, #T_086a5_row7_col8, #T_086a5_row12_col3, #T_086a5_row12_col21, #T_086a5_row12_col22, #T_086a5_row12_col24, #T_086a5_row23_col14, #T_086a5_row24_col21 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_086a5_row0_col21 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_086a5_row0_col22, #T_086a5_row2_col5, #T_086a5_row7_col15, #T_086a5_row9_col7, #T_086a5_row10_col21, #T_086a5_row18_col7 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_086a5_row0_col24, #T_086a5_row13_col15, #T_086a5_row16_col4, #T_086a5_row16_col12, #T_086a5_row18_col9, #T_086a5_row23_col17 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_086a5_row0_col25, #T_086a5_row25_col0 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_086a5_row0_col26, #T_086a5_row1_col26, #T_086a5_row2_col26, #T_086a5_row3_col26, #T_086a5_row4_col26, #T_086a5_row5_col26, #T_086a5_row6_col26, #T_086a5_row7_col26, #T_086a5_row8_col26, #T_086a5_row9_col26, #T_086a5_row10_col26, #T_086a5_row11_col26, #T_086a5_row12_col26, #T_086a5_row13_col26, #T_086a5_row14_col26, #T_086a5_row15_col26, #T_086a5_row16_col26, #T_086a5_row17_col26, #T_086a5_row18_col26, #T_086a5_row19_col26, #T_086a5_row20_col26, #T_086a5_row21_col26, #T_086a5_row22_col26, #T_086a5_row23_col26, #T_086a5_row24_col26, #T_086a5_row25_col26, #T_086a5_row26_col0, #T_086a5_row26_col1, #T_086a5_row26_col2, #T_086a5_row26_col3, #T_086a5_row26_col4, #T_086a5_row26_col5, #T_086a5_row26_col6, #T_086a5_row26_col7, #T_086a5_row26_col8, #T_086a5_row26_col9, #T_086a5_row26_col10, #T_086a5_row26_col11, #T_086a5_row26_col12, #T_086a5_row26_col13, #T_086a5_row26_col14, #T_086a5_row26_col15, #T_086a5_row26_col16, #T_086a5_row26_col17, #T_086a5_row26_col18, #T_086a5_row26_col19, #T_086a5_row26_col20, #T_086a5_row26_col21, #T_086a5_row26_col22, #T_086a5_row26_col23, #T_086a5_row26_col24, #T_086a5_row26_col25, #T_086a5_row26_col26 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_086a5_row1_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_086a5_row1_col2, #T_086a5_row9_col12 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_086a5_row1_col3 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_086a5_row1_col4, #T_086a5_row8_col16, #T_086a5_row11_col24 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_086a5_row1_col6, #T_086a5_row8_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_086a5_row1_col7 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_086a5_row1_col8, #T_086a5_row2_col10, #T_086a5_row19_col0, #T_086a5_row19_col9, #T_086a5_row20_col0, #T_086a5_row20_col9, #T_086a5_row23_col4 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_086a5_row1_col9, #T_086a5_row11_col19, #T_086a5_row11_col20, #T_086a5_row18_col8 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_086a5_row1_col10, #T_086a5_row2_col14, #T_086a5_row12_col9, #T_086a5_row13_col8, #T_086a5_row13_col19, #T_086a5_row13_col20, #T_086a5_row22_col12, #T_086a5_row25_col8 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_086a5_row1_col11, #T_086a5_row19_col13, #T_086a5_row20_col13 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_086a5_row1_col12, #T_086a5_row4_col9, #T_086a5_row4_col15, #T_086a5_row8_col24, #T_086a5_row10_col23, #T_086a5_row13_col24 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_086a5_row1_col13, #T_086a5_row15_col8 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_086a5_row1_col14, #T_086a5_row8_col5, #T_086a5_row8_col12 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_086a5_row1_col15, #T_086a5_row11_col8, #T_086a5_row19_col11, #T_086a5_row20_col11 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_086a5_row1_col16, #T_086a5_row10_col12, #T_086a5_row18_col4 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_086a5_row1_col17, #T_086a5_row4_col11, #T_086a5_row8_col6 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_086a5_row1_col18, #T_086a5_row19_col2, #T_086a5_row20_col2, #T_086a5_row24_col13 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_086a5_row1_col19, #T_086a5_row1_col20, #T_086a5_row8_col14 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_086a5_row1_col21 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_086a5_row1_col22, #T_086a5_row2_col4, #T_086a5_row4_col13 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_086a5_row1_col23, #T_086a5_row2_col19, #T_086a5_row2_col20, #T_086a5_row8_col3 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_086a5_row1_co

# %%
exclude=['profile_validity']

# %%
numerical_columns=list(ch_data.select_dtypes(include='number').columns)
for feature in numerical_columns:
    if feature in exclude:
        pass
    else:
        numerical_columns.remove(feature)
print(numerical_columns)
# Out:
# ['user_id', 'total_accounts', 'positive_status_accounts', 'closed_accounts', 'credit_utilization', 'seasoning', 'portfolio_mix_unsecured', 'annual_income', 'minor_issues', 'no_of_delayed_payments', 'no_of_active_accounts', 'credit_utilization_avg', 'sub', 'profile_validity']

# %%
skewed=[]
def find_skew(data,numerical_columns):
    skew_list={}
    for feature in numerical_columns:
        try:
            try:
                skew_value=(3*(data[feature].mean()-data[feature].median()))/data[feature].std()
                if ((round(skew_value,2)<-3) or (round(skew_value,2)>3)):
                    skew_list[feature]='Skewwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww'
                    skewed.append(feature)
                else:
                    skew_list[feature]=round(skew_value,2)
            except ZeroDivisionError:
                skew_list[feature]='Skewwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww'
                skewed.append(feature)
        except:
            pass
    return skew_list
skew_list=find_skew(ch_data,numerical_columns)
skew_list
# Out:
# {'user_id': -0.54,
#  'total_accounts': 0.86,
#  'positive_status_accounts': 0.32,
#  'closed_accounts': 0.89,
#  'credit_utilization': 1.53,
#  'seasoning': 1.64,
#  'portfolio_mix_unsecured': -1.24,
#  'annual_income': 1.12,
#  'minor_issues': 0.89,
#  'no_of_delayed_payments': 1.82,
#  'no_of_active_accounts': 0.85,
#  'credit_utilization_avg': 1.62,
#  'sub': 2.67,
#  'profile_validity': 'Skewwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww'}

# %%
for i in numerical_columns:
    if i in exclude:
        pass
    else:
        try:
            ch_data[i] =stats.boxcox(array)
        except:
            pass
find_skew(ch_data,numerical_columns)
# Out:
# {'user_id': -0.54,
#  'total_accounts': 0.86,
#  'positive_status_accounts': 0.32,
#  'closed_accounts': 0.89,
#  'credit_utilization': 1.53,
#  'seasoning': 1.64,
#  'portfolio_mix_unsecured': -1.24,
#  'annual_income': 1.12,
#  'minor_issues': 0.89,
#  'no_of_delayed_payments': 1.82,
#  'no_of_active_accounts': 0.85,
#  'credit_utilization_avg': 1.62,
#  'sub': 2.67,
#  'profile_validity': 'Skewwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww'}

# %%
joblib.dump(ch_data, 'ch_transformed_data_AL.pkl')
# Out:
# ['ch_transformed_data_AL.pkl']

# %%
user_ids=pd.concat([ch_data['user_id'].reset_index(drop = True)], axis = 1)
ch_data.drop(['user_id'],axis=1,inplace=True)

# %%
customer_profile_id=pd.concat([ch_data['customer_profile_id'].reset_index(drop = True)], axis = 1)
ch_data.drop(['customer_profile_id'],axis=1,inplace=True)

# %%
categorical_features=list(ch_data.select_dtypes(exclude='number').columns)
categorical_features
# Out:
# ['p_occupation', 'p_equifax_income', 'p_customer_type']

# %%
exemption_features=['sub']

# %%
numeric_features=list(ch_data.select_dtypes(include='number').columns)
numeric_features
flag_features=[]
for feature in exemption_features:
    numeric_features.remove(feature)
for feature in exclude:
    if feature in numeric_features:
        flag_features.append(feature)
        numeric_features.remove(feature)

# %%
id_columns=['user_id','customer_profile_id']
exemption_features=['sub']

# %%
dummies = pd.get_dummies(data = ch_data[categorical_features], drop_first=False)
dummies.columns
# Out:
# Index(['p_occupation_Other', 'p_occupation_Salaried',
#        'p_occupation_SelfEmployed', 'p_equifax_income_10-15k',
#        'p_equifax_income_15-20k', 'p_equifax_income_20-25k',
#        'p_equifax_income_25-30k', 'p_equifax_income_30-35k',
#        'p_equifax_income_35-40k', 'p_equifax_income_40-45k',
#        'p_equifax_income_<10k', 'p_equifax_income_Other',
#        'p_customer_type_Amber', 'p_customer_type_Green',
#        'p_customer_type_Red'],
#       dtype='object')

# %%
'''Scaling numeric features'''
standard_scalar = StandardScaler(with_mean=True,with_std=True)
standard_scalar.fit(ch_data[numeric_features])
numeric_data_scaled = standard_scalar.transform(ch_data[numeric_features])
numeric_data_scaled = pd.DataFrame(numeric_data_scaled,columns=numeric_features)
numeric_data_scaled.head()
# Out:
#    p_credit_score  total_accounts  negative_status_accounts  \
# 0            0.79           -0.92                     -0.79
# 1            0.79           -0.64                     -0.79
# 2            0.79           -0.71                     -0.79
# 3            0.66           -0.36                      0.43
# 4            0.04           -0.50                      0.43
#
#    positive_status_accounts  open_accounts  closed_accounts  max_dpd  \
# 0                     -1.06          -0.58            -1.23    -0.21
# 1                     -0.58          -1.28            -0.14    -0.21
# 2                     -0.70          -0.58            -0.76    -0.21
# 3                     -0.23          -0.81             0.17    -0.21
# 4                     -0.46          -0.58            -0.30    -0.21
#
#    credit_utilization  enquiries_made  seasoning  portfolio_mix_secured  \
# 0               -0.51            0.20       0.24                  -0.60
# 1               -0.51           -0.64      -0.94                  -0.60
# 2                1.10           -0.22      -0.15                   1.18
# 3               -0.51           -0.64      -0.55                  -0.60
# 4               -0.51           -0.64      -0.94                  -0.60
#
#    portfolio_mix_unsecured  related_accounts  annual_income  calculated_emi  \
# 0                     0.89             -0.63          -0.24           -0.66
# 1                    -1.51             -0.63          -0.24           -0.83
# 2                    -0.31              0.02          -0.37           -0.82
# 3                     0.89             -0.63          -0.37           -0.40
# 4                     0.89              1.33          -0.37            1.52
#
#    minor_issues  ontime_payment_percentage  no_of_delayed_payments  \
# 0         -0.79                       0.75                   -0.61
# 1         -0.79                      -1.89                   -0.61
# 2         -0.30                       0.19                    0.09
# 3         -0.30                       0.75                   -0.61
# 4         -0.30                      -0.11                    0.55
#
#    no_of_delayed_payments_on_active_accounts  no_of_active_accounts  \
# 0                                      -0.61                  -0.28
# 1                                      -0.61                  -1.20
# 2                                       0.09                  -0.59
# 3                                      -0.61                  -0.90
# 4                                       0.55                  -0.59
#
#    existing_foir  credit_utilization_avg  is_saleable
# 0          -0.40                   -0.54        -0.52
# 1          -0.52                   -0.54        -0.52
# 2          -0.52                    1.14        -0.52
# 3          -0.52                   -0.54        -0.52
# 4          -0.52                   -0.54        -0.52

# %%
'''Concatenating all features'''
processed_dataset = pd.concat([user_ids['user_id'].reset_index(drop = True), 
                               customer_profile_id['customer_profile_id'].reset_index(drop = True), 
                               numeric_data_scaled.reset_index(drop = True),
                               ch_data[flag_features].reset_index(drop = True),
                               dummies.reset_index(drop = True),
                              ch_data[exemption_features].reset_index(drop = True)
                              ], axis=1)
processed_dataset.shape
# Out:
# (12542, 42)

# %%
joblib.dump(processed_dataset, 'ch_processed_data_AL.pkl')
# Out:
# ['ch_processed_data_AL.pkl']

# %%
processed_dataset.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\style.py:3555: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\style.py:3556: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_64291_row0_col0, #T_64291_row1_col1, #T_64291_row2_col2, #T_64291_row3_col3, #T_64291_row4_col4, #T_64291_row5_col5, #T_64291_row6_col6, #T_64291_row7_col7, #T_64291_row8_col8, #T_64291_row9_col9, #T_64291_row10_col10, #T_64291_row11_col11, #T_64291_row12_col12, #T_64291_row13_col13, #T_64291_row14_col14, #T_64291_row15_col15, #T_64291_row16_col16, #T_64291_row17_col17, #T_64291_row18_col18, #T_64291_row19_col19, #T_64291_row19_col20, #T_64291_row20_col19, #T_64291_row20_col20, #T_64291_row21_col21, #T_64291_row22_col22, #T_64291_row23_col23, #T_64291_row24_col24, #T_64291_row26_col26, #T_64291_row27_col27, #T_64291_row28_col28, #T_64291_row29_col29, #T_64291_row30_col30, #T_64291_row31_col31, #T_64291_row32_col32, #T_64291_row33_col33, #T_64291_row34_col34, #T_64291_row35_col35, #T_64291_row36_col36, #T_64291_row37_col37, #T_64291_row38_col38, #T_64291_row39_col39, #T_64291_row40_col40, #T_64291_row41_col41 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_64291_row0_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_64291_row0_col2, #T_64291_row9_col12, #T_64291_row10_col40, #T_64291_row19_col0, #T_64291_row20_col0, #T_64291_row29_col12, #T_64291_row30_col33, #T_64291_row30_col34, #T_64291_row31_col9, #T_64291_row31_col28, #T_64291_row32_col19, #T_64291_row32_col20, #T_64291_row33_col6, #T_64291_row33_col10, #T_64291_row34_col21, #T_64291_row36_col18, #T_64291_row36_col19, #T_64291_row36_col20, #T_64291_row37_col30 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_64291_row0_col3 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_64291_row0_col4, #T_64291_row29_col30, #T_64291_row29_col38, #T_64291_row31_col29, #T_64291_row32_col33, #T_64291_row32_col34, #T_64291_row33_col41, #T_64291_row34_col19, #T_64291_row34_col20 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_64291_row0_col5, #T_64291_row1_col0, #T_64291_row2_col38, #T_64291_row3_col37, #T_64291_row4_col39, #T_64291_row5_col37, #T_64291_row6_col37, #T_64291_row7_col37, #T_64291_row8_col39, #T_64291_row9_col0, #T_64291_row10_col37, #T_64291_row11_col37, #T_64291_row12_col13, #T_64291_row13_col12, #T_64291_row14_col0, #T_64291_row15_col37, #T_64291_row16_col0, #T_64291_row17_col37, #T_64291_row18_col38, #T_64291_row19_col39, #T_64291_row20_col39, #T_64291_row21_col37, #T_64291_row22_col37, #T_64291_row23_col0, #T_64291_row24_col39, #T_64291_row26_col27, #T_64291_row27_col26, #T_64291_row28_col26, #T_64291_row29_col37, #T_64291_row30_col37, #T_64291_row31_col37, #T_64291_row32_col37, #T_64291_row33_col37, #T_64291_row34_col37, #T_64291_row35_col37, #T_64291_row36_col37, #T_64291_row37_col35, #T_64291_row38_col2, #T_64291_row39_col40, #T_64291_row40_col39, #T_64291_row41_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_64291_row0_col6, #T_64291_row5_col0, #T_64291_row39_col4 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_64291_row0_col7 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_64291_row0_col8, #T_64291_row0_col28, #T_64291_row1_col32, #T_64291_row9_col27, #T_64291_row15_col19, #T_64291_row15_col20, #T_64291_row18_col30, #T_64291_row23_col4, #T_64291_row35_col32, #T_64291_row35_col36, #T_64291_row41_col34 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_64291_row0_col9, #T_64291_row33_col12, #T_64291_row33_col28, #T_64291_row36_col34 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_64291_row0_col10, #T_64291_row8_col14, #T_64291_row9_col40, #T_64291_row11_col28, #T_64291_row12_col9, #T_64291_row13_col8, #T_64291_row13_col19, #T_64291_row13_col20, #T_64291_row14_col32, #T_64291_row17_col32, #T_64291_row32_col22, #T_64291_row41_col8, #T_64291_row41_col39 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_64291_row0_col11, #T_64291_row8_col41, #T_64291_row14_col26, #T_64291_row17_col39, #T_64291_row29_col28, #T_64291_row34_col17, #T_64291_row36_col13, #T_64291_row36_col23, #T_64291_row36_col27 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_64291_row0_col12, #T_64291_row0_col27, #T_64291_row6_col26, #T_64291_row8_col17, #T_64291_row11_col31, #T_64291_row11_col36, #T_64291_row12_col39, #T_64291_row13_col24, #T_64291_row17_col33, #T_64291_row17_col36, #T_64291_row30_col3, #T_64291_row31_col5 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_64291_row0_col13, #T_64291_row8_col36, #T_64291_row9_col30, #T_64291_row10_col29, #T_64291_row11_col24, #T_64291_row15_col31, #T_64291_row29_col6, #T_64291_row29_col8, #T_64291_row29_col11, #T_64291_row29_col21, #T_64291_row30_col12, #T_64291_row30_col23, #T_64291_row31_col18, #T_64291_row32_col4, #T_64291_row32_col17, #T_64291_row36_col17, #T_64291_row36_col24, #T_64291_row36_col41 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_64291_row0_col14, #T_64291_row33_col34, #T_64291_row34_col26, #T_64291_row34_col39, #T_64291_row36_col30, #T_64291_row41_col38 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_64291_row0_col15, #T_64291_row23_col26, #T_64291_row29_col1, #T_64291_row29_col14, #T_64291_row29_col32, #T_64291_row32_col12, #T_64291_row32_col39, #T_64291_row33_col2, #T_64291_row33_col4, #T_64291_row33_col13, #T_64291_row33_col16, #T_64291_row34_col4, #T_64291_row34_col14, #T_64291_row34_col16 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_64291_row0_col16, #T_64291_row6_col38, #T_64291_row16_col37, #T_64291_row36_col35 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_64291_row0_col17, #T_64291_row8_col11, #T_64291_row8_col37, #T_64291_row9_col26, #T_64291_row29_col31, #T_64291_row30_col38, #T_64291_row31_col16, #T_64291_row31_col36, #T_64291_row33_col9, #T_64291_row33_col19, #T_64291_row33_col20, #T_64291_row33_col24, #T_64291_row33_col40, #T_64291_row34_col40, #T_64291_row34_col41 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_64291_row0_col18, #T_64291_row8_col23, #T_64291_row8_col26, #T_64291_row8_col29, #T_64291_row8_col34, #T_64291_row10_col24, #T_64291_row10_col36, #T_64291_row11_col4, #T_64291_row16_col26, #T_64291_row24_col0, #T_64291_row29_col18, #T_64291_row31_col8, #T_64291_row31_col12, #T_64291_row32_col14, #T_64291_row32_col28, #T_64291_row37_col17 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_64291_row0_col19, #T_64291_row0_col20, #T_64291_row8_col30, #T_64291_row8_col31, #T_64291_row15_col30, #T_64291_row29_col9, #T_64291_row30_col32, #T_64291_row30_col36, #T_64291_row30_col41, #T_64291_row31_col0, #T_64291_row31_col39, #T_64291_row32_col8, #T_64291_row32_col23, #T_64291_row33_col11, #T_64291_row33_col17, #T_64291_row36_col8, #T_64291_row36_col9, #T_64291_row36_col11 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_64291_row0_col21, #T_64291_row11_col38, #T_64291_row14_col37 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_64291_row0_col22, #T_64291_row8_col27, #T_64291_row10_col28, #T_64291_row29_col33, #T_64291_row29_col34, #T_64291_row30_col31, #T_64291_row31_col1, #T_64291_row31_col41, #T_64291_row32_col27, #T_64291_row34_col10, #T_64291_row35_col0, #T_64291_row36_col10, #T_64291_row37_col16 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_64291_row0_col23, #T_64291_row8_col0, #T_64291_row18_col0, #T_64291_row29_col16, #T_64291_row32_col26, #T_64291_row33_col14, #T_64291_row33_col27, #T_64291_row34_col24 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_64291_row0_col24, #T_64291_row0_col40, #T_64291_row8_col13, #T_64291_row10_col12, #T_64291_row29_col41, #T_64291_row31_col32, #T_64291_row33_col18, #T_64291_row34_col1, #T_64291_row34_col2, #T_64291_row36_col39 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_64291_row0_col25, #T_64291_row1_col25, #T_64291_row2_col25, #T_64291_row3_col25, #T_64291_row4_col25, #T_64291_row5_col25, #T_64291_row6_col25, #T_64291_row7_col25, #T_64291_row8_col25, #T_64291_row9_col25, #T_64291_row10_col25, #T_64291_row11_col25, #T_64291_row12_col25, #T_64291_row13_col25, #T_64291_row14_col25, #T_64291_row15_col25, #T_64291_row16_col25, #T_64291_row17_col25, #T_64291_row18_col25, #T_64291_row19_col25, #T_64291_row20_col25, #T_64291_row21_col25, #T_64291

# %%
ch_data.describe(percentiles=[0.01,0.05,0.10,0.25,0.5,0.75,0.9,0.95,0.99],datetime_is_numeric=True).transpose()
# Out:
#                                              count     mean       std  min  \
# p_credit_score                            12542.00   617.03    200.28 0.00
# total_accounts                            12542.00    16.09     14.28 0.00
# negative_status_accounts                  12542.00     0.65      0.82 0.00
# positive_status_accounts                  12542.00    11.91      8.44 0.00
# open_accounts                             12542.00     5.51      4.32 0.00
# closed_accounts                           12542.00     7.92      6.46 0.00
# max_dpd                                   12542.00     4.51     21.33 0.00
# credit_utilization                        12542.00    16.26     31.98 0.00
# enquiries_made                            12542.00     1.52      2.38 0.00
# seasoning                                 12542.00     2.39      2.54 0.00
# portfolio_mix_secured                     12542.00     0.17      0.28 0.00
# portfolio_mix_unsecured                   12542.00     0.63      0.42 0.00
# related_accounts                          12542.00     0.97      1.53 0.00
# annual_income                             12542.00 84474.54 146207.32 1.00
# calculated_emi                            12542.00 22050.23  26462.24 0.00
# minor_issues                              12542.00     1.59      2.01 0.00
# ontime_payment_percentage                 12542.00    71.56     37.77 0.00
# no_of_delayed_payments                    12542.00     7.88     12.98 0.00
# no_of_delayed_payments_on_active_accounts 12542.00     7.88     12.98 0.00
# no_of_active_accounts                     12542.00     3.93      3.26 0.00
# existing_foir                             12542.00   500.69    971.03 0.00
# credit_utilization_avg                    12542.00    16.77     30.99 0.00
# is_saleable                               12542.00     0.49      0.93 0.00
# sub                                       12542.00     0.44      0.50 0.00
# profile_validity                          12542.00     1.00      0.00 1.00
#
#                                               1%       5%      10%      25%  \
# p_credit_score                              0.00     0.00   525.00   575.00
# total_accounts                              0.00     0.00     1.00     5.00
# negative_status_accounts                    0.00     0.00     0.00     0.00
# positive_status_accounts                    0.00     0.00     1.00     4.00
# open_accounts                               0.00     0.00     1.00     2.00
# closed_accounts                             0.00     0.00     0.00     2.00
# max_dpd                                     0.00     0.00     0.00     0.00
# credit_utilization                          0.00     0.00     0.00     0.00
# enquiries_made                              0.00     0.00     0.00     0.00
# seasoning                                   0.00     0.00     0.00     0.00
# portfolio_mix_secured                       0.00     0.00     0.00     0.00
# portfolio_mix_unsecured                     0.00     0.00     0.00     0.00
# related_accounts                            0.00     0.00     0.00     0.00
# annual_income                             350.00 13000.00 16500.00 30000.00
# calculated_emi                              0.00     0.00     0.00  1295.10
# minor_issues                                0.00     0.00     0.00     0.00
# ontime_payment_percentage                   0.00     0.00     0.00    50.00
# no_of_delayed_payments                      0.00     0.00     0.00     0.00
# no_of_delayed_payments_on_active_accounts   0.00     0.00     0.00     0.00
# no_of_active_accounts                       0.00     0.00     0.00     1.00
# existing_foir                               0.00     0.00     0.00     0.00
# credit_utilization_avg                      0.00     0.00     0.00     0.00
# is_saleable                                 0.00     0.00     0.00     0.00
# sub                                         0.00     0.00     0.00     0.00
# profile_validity                            1.00     1.00     1.00     1.00
#
#                                                50%      75%       90%  \
# p_credit_score                              675.00   725.00    750.00
# total_accounts                               12.00    24.00     42.00
# negative_status_accounts                      0.00     1.00      2.00
# positive_status_accounts                     11.00    23.00     23.00
# open_accounts                                 5.00     8.00     13.00
# closed_accounts                               6.00    16.00     17.00
# max_dpd                                       0.00     0.00      0.00
# credit_utilization                            0.00     5.32     81.87
# enquiries_made                                1.00     2.00      4.00
# seasoning                                     1.00     4.00      7.00
# portfolio_mix_secured                         0.00     0.25      0.50
# portfolio_mix_unsecured                       0.80     1.00      1.00
# related_accounts                              0.00     1.00      4.00
# annual_income                             30000.00 40000.00 300000.00
# calculated_emi                             9443.01 34736.75  75000.00
# minor_issues                                  1.00     2.00      4.00
# ontime_payment_percentage                    93.85   100.00    100.00
# no_of_delayed_payments                        0.00    11.00     28.00
# no_of_delayed_payments_on_active_accounts     0.00    11.00     28.00
# no_of_active_accounts                         3.00     6.00     10.00
# existing_foir                                 0.00   470.67   1946.26
# credit_utilization_avg                        0.00    18.00     75.00
# is_saleable                                   0.00     1.00      2.00
# sub                                           0.00     1.00      1.00
# profile_validity                              1.00     1.00      1.00
#
#                                                 95%       99%       max
# p_credit_score                               775.00    775.00    775.00
# total_accounts                                47.00     47.00     47.00
# negative_status_accounts                       2.00      2.00      2.00
# positive_status_accounts                      23.00     23.00     23.00
# open_accounts                                 14.00     14.00     14.00
# closed_accounts                               17.00     17.00     17.00
# max_dpd                                        0.00    120.00    120.00
# credit_utilization                            98.92    100.00    100.00
# enquiries_made                                 6.00     12.00     13.00
# seasoning                                      8.00      8.00      8.00
# portfolio_mix_secured                          1.00      1.00      1.00
# portfolio_mix_unsecured                        1.00      1.00      1.00
# related_accounts                               5.00      5.00      5.00
# annual_income                             560000.00 560000.00 560000.00
# calculated_emi                             75000.00  75000.00  75000.00
# minor_issues                                   6.00     10.00     10.00
# ontime_payment_percentage                    100.00    100.00    100.00
# no_of_delayed_payments                        44.95     45.00     45.00
# no_of_delayed_payments_on_active_accounts     44.95     45.00     45.00
# no_of_active_accounts                         10.00     10.00     10.00
# existing_foir                               3500.00   3500.00   3500.00
# credit_utilization_avg                        98.00    100.00    100.00
# is_saleable                                    3.00      4.00      4.00
# sub                                            1.00      1.00      1.00
# profile_validity                               1.00      1.00      1.00

# %%
'''Replace Infinite'''
processed_dataset = processed_dataset.replace([np.inf, -np.inf], np.nan).dropna(axis=0)
processed_dataset.shape
# Out:
# (12542, 42)

# %%
# data=processed_dataset[[
# 'p_customer_type_Red',
# 'p_customer_type_Green',
# 'p_occupation_Salaried',
# 'p_equifax_income_Other',
# 'p_occupation_SelfEmployed',
# 'p_occupation_Other',
# 'p_equifax_income_40-45k',
# 'negative_status_accounts',
# 'is_saleable',
# 'credit_utilization',
# 'credit_utilization_avg',
# 'portfolio_mix_secured',
# 'no_of_delayed_payments_on_active_accounts',
# 'no_of_delayed_payments',
# 'related_accounts',
# 'portfolio_mix_unsecured',
# 'open_accounts',
# 'enquiries_made',
# 'no_of_active_accounts',
# 'minor_issues',
# 'closed_accounts',
# 'annual_income',
# 'existing_foir',
# 'seasoning',
# 'ontime_payment_percentage',
# 'p_credit_score',
# 'positive_status_accounts',
# 'total_accounts',
# 'calculated_emi',
# ]]

# %%
'''  Splitting test and train data '''
data=processed_dataset.drop(['customer_profile_id','profile_validity'],axis=1)

X = data.loc[:,data.columns != 'sub']
y = data['sub']
train_X_u,test_X_u,train_y,test_y = train_test_split(X,y,random_state=13,test_size=0.1)
train_X = train_X_u.loc[:,train_X_u.columns != 'user_id']
test_X = test_X_u.loc[:,test_X_u.columns != 'user_id']

# %%
train_X.head()
# Out:
#       p_credit_score  total_accounts  negative_status_accounts  \
# 5151            0.29            0.55                     -0.79
# 9641            0.66           -0.64                     -0.79
# 5222           -0.33            1.53                      1.66
# 519             0.16            0.13                     -0.79
# 2911            0.16            0.34                     -0.79
#
#       positive_status_accounts  open_accounts  closed_accounts  max_dpd  \
# 5151                      1.31           0.11             1.40    -0.21
# 9641                     -0.58          -0.58            -0.61    -0.21
# 5222                      1.31           1.97             1.40    -0.21
# 519                       0.72           0.34             0.48    -0.21
# 2911                      1.08           1.27             0.32    -0.21
#
#       credit_utilization  enquiries_made  seasoning  portfolio_mix_secured  \
# 5151                0.11           -0.64      -0.94                  -0.60
# 9641               -0.51            1.04       0.24                  -0.60
# 5222               -0.16            3.98       2.21                  -0.60
# 519                 2.23           -0.64       1.42                   0.58
# 2911                0.46           -0.64       0.63                   0.01
#
#       portfolio_mix_unsecured  related_accounts  annual_income  \
# 5151                     0.89             -0.63          -0.34
# 9641                     0.89              0.02          -0.37
# 5222                     0.89              2.64          -0.37
# 519                      0.10             -0.63          -0.34
# 2911                     0.49              1.99           3.25
#
#       calculated_emi  minor_issues  ontime_payment_percentage  \
# 5151           -0.43         -0.30                       0.75
# 9641           -0.40         -0.79                       0.75
# 5222            2.00          2.69                       0.30
# 519             2.00         -0.30                       0.72
# 2911            0.51          1.69                       0.70
#
#       no_of_delayed_payments  no_of_delayed_payments_on_active_accounts  \
# 5151                   -0.61                                      -0.61
# 9641                   -0.61                                      -0.61
# 5222                    1.32                                       1.32
# 519                    -0.53                                      -0.53
# 2911                   -0.38                                      -0.38
#
#       no_of_active_accounts  existing_foir  credit_utilization_avg  \
# 5151                   0.33          -0.14                    0.01
# 9641                  -0.28          -0.52                   -0.54
# 5222                   1.86          -0.52                   -0.35
# 519                    0.63           3.09                    2.30
# 2911                   0.63          -0.49                   -0.35
#
#       is_saleable  p_occupation_Other  p_occupation_Salaried  \
# 5151        -0.52                   1                      0
# 9641        -0.52                   1                      0
# 5222         0.55                   1                      0
# 519         -0.52                   0                      1
# 2911        -0.52                   0                      1
#
#       p_occupation_SelfEmployed  p_equifax_income_10-15k  \
# 5151                          0                        0
# 9641                          0                        0
# 5222                          0                        0
# 519                           0                        0
# 2911                          0                        0
#
#       p_equifax_income_15-20k  p_equifax_income_20-25k  \
# 5151                        0                        0
# 9641                        0                        0
# 5222                        0                        0
# 519                         0                        0
# 2911                        0                        0
#
#       p_equifax_income_25-30k  p_equifax_income_30-35k  \
# 5151                        0                        1
# 9641                        0                        0
# 5222                        0                        0
# 519                         0                        1
# 2911                        0                        0
#
#       p_equifax_income_35-40k  p_equifax_income_40-45k  p_equifax_income_<10k  \
# 5151                        0                        0                      0
# 9641                        0                        0                      0
# 5222                        0                        0                      0
# 519                         0                        0                      0
# 2911                        0                        1                      0
#
#       p_equifax_income_Other  p_customer_type_Amber  p_customer_type_Green  \
# 5151                       0                      0                      1
# 9641                       1                      0                      1
# 5222                       1                      0                      0
# 519                        0                      0                      1
# 2911                       0                      0                      1
#
#       p_customer_type_Red
# 5151                    0
# 9641                    0
# 5222                    1
# 519                     0
# 2911                    0

# %%
#RandomForest
''' Tuning Grid '''
gridParams = {
#                 'n_estimators': [100],
#                 'max_features':['sqrt'],
#                 'bootstrap': [True],
                'random_state' : [12],
#                 'warm_start':[False],
                'criterion':['gini', 'entropy'],
#                 'max_depth':[47],
                'min_samples_split':[0.00000002,0.00000003,0.00000004,0.00000005],
                'min_samples_leaf':[0.0000002,0.0000003,0.0000004,0.0000005]
             }

'''Model Object'''
model2 = RandomForestClassifier()

''' Grid Formation '''
grid = RandomizedSearchCV(estimator = model2 , param_distributions= gridParams, verbose = 2, cv = 3, n_iter=1000)
grid.fit(train_X, train_y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:292: UserWarning: The total space of parameters 32 is smaller than n_iter=1000. Running 32 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=2e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=2e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=2e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=3e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=3e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=3e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=4e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=4e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=4e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=5e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=5e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=2e-07, min_samples_split=5e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=3e-07, min_samples_split=2e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=3e-07, min_samples_split=2e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=3e-07, min_samples_split=2e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=3e-07, min_samples_split=3e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=3e-07, min_samples_split=3e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=3e-07, min_samples_split=3e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=3e-07, min_samples_split=4e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=3e-07, min_samples_split=4e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=3e-07, min_samples_split=4e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=3e-07, min_samples_split=5e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=3e-07, min_samples_split=5e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=3e-07, min_samples_split=5e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=4e-07, min_samples_split=2e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=4e-07, min_samples_split=2e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=4e-07, min_samples_split=2e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=4e-07, min_samples_split=3e-08, random_state=12; total time=   0.6s
# [CV] END criterion=gini, min_samples_leaf=4e-07, min_samples_split=3e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=4e-07, min_samples_split=3e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=4e-07, min_samples_split=4e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=4e-07, min_samples_split=4e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=4e-07, min_samples_split=4e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=4e-07, min_samples_split=5e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=4e-07, min_samples_split=5e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=4e-07, min_samples_split=5e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=5e-07, min_samples_split=2e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=5e-07, min_samples_split=2e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=5e-07, min_samples_split=2e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=5e-07, min_samples_split=3e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=5e-07, min_samples_split=3e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=5e-07, min_samples_split=3e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=5e-07, min_samples_split=4e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=5e-07, min_samples_split=4e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=5e-07, min_samples_split=4e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=5e-07, min_samples_split=5e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=5e-07, min_samples_split=5e-08, random_state=12; total time=   0.7s
# [CV] END criterion=gini, min_samples_leaf=5e-07, min_samples_split=5e-08, random_state=12; total time=   0.7s
# [CV] END criterion=entropy, min_samples_leaf=2e-07, min_samples_split=2e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=2e-07, min_samples_split=2e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=2e-07, min_samples_split=2e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=2e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=2e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=2e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=2e-07, min_samples_split=4e-08, random_state=12; total time=   0.9s
# [CV] END criterion=entropy, min_samples_leaf=2e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=2e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=2e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=2e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=2e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=3e-07, min_samples_split=2e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=3e-07, min_samples_split=2e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=3e-07, min_samples_split=2e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=3e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=3e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=3e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=3e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=3e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=3e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=3e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=3e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=3e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=4e-07, min_samples_split=2e-08, random_state=12; total time=   0.9s
# [CV] END criterion=entropy, min_samples_leaf=4e-07, min_samples_split=2e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=4e-07, min_samples_split=2e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=4e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=4e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=4e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=4e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=4e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=4e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=4e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=4e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=4e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=5e-07, min_samples_split=2e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=5e-07, min_samples_split=2e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=5e-07, min_samples_split=2e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=5e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=5e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=5e-07, min_samples_split=3e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=5e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=5e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=5e-07, min_samples_split=4e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=5e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=5e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# [CV] END criterion=entropy, min_samples_leaf=5e-07, min_samples_split=5e-08, random_state=12; total time=   0.8s
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(), n_iter=1000,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'min_samples_leaf': [2e-07, 3e-07,
#                                                              4e-07, 5e-07],
#                                         'min_samples_split': [2e-08, 3e-08,
#                                                               4e-08, 5e-08],
#                                         'random_state': [12]},
#                    verbose=2)

# %%
#RandomForest

'''Model Object'''
model = RandomForestClassifier(criterion='entropy', min_samples_split=0.007, min_samples_leaf=0.0001,  random_state=15)
model.fit(train_X, train_y)
# Out:
# RandomForestClassifier(criterion='entropy', min_samples_leaf=0.0001,
#                        min_samples_split=0.007, random_state=15)

# %%
dict(sorted(dict(zip(grid.feature_names_in_, model.feature_importances_)).items(), key=lambda item: item[1]))
# Out:
# {'p_equifax_income_35-40k': 0.000840759636746339,
#  'p_equifax_income_<10k': 0.0012291926403441415,
#  'p_equifax_income_30-35k': 0.0014166076722087,
#  'p_equifax_income_25-30k': 0.0015594624367703388,
#  'p_occupation_Salaried': 0.002229423003221367,
#  'p_occupation_Other': 0.0023750912763810792,
#  'p_equifax_income_20-25k': 0.0023870526078959577,
#  'p_occupation_SelfEmployed': 0.0025630058925737477,
#  'max_dpd': 0.0027478963305768507,
#  'p_equifax_income_10-15k': 0.0029928562548913067,
#  'p_customer_type_Green': 0.0030259107448792244,
#  'p_equifax_income_15-20k': 0.0034230344106855313,
#  'p_equifax_income_Other': 0.003893107639403112,
#  'p_customer_type_Red': 0.004377650354110502,
#  'p_customer_type_Amber': 0.00541366791592326,
#  'negative_status_accounts': 0.0066731215192579385,
#  'p_equifax_income_40-45k': 0.010635743615131558,
#  'no_of_delayed_payments': 0.012209415639807883,
#  'enquiries_made': 0.013307158935951977,
#  'no_of_delayed_payments_on_active_accounts': 0.015023151075070186,
#  'is_saleable': 0.017889805533838135,
#  'credit_utilization_avg': 0.020948597946791953,
#  'credit_utilization': 0.022110794853119654,
#  'existing_foir': 0.02423574124922107,
#  'p_credit_score': 0.027743068822902797,
#  'related_accounts': 0.030482204277843997,
#  'seasoning': 0.031213337531113196,
#  'open_accounts': 0.032716922583362035,
#  'annual_income': 0.03447112103152875,
#  'closed_accounts': 0.03789551634865576,
#  'portfolio_mix_unsecured': 0.041069014000718634,
#  'total_accounts': 0.0499337574601356,
#  'minor_issues': 0.05501855713489532,
#  'ontime_payment_percentage': 0.05875959565819891,
#  'positive_status_accounts': 0.059051818393183506,
#  'portfolio_mix_secured': 0.06282721877607603,
#  'no_of_active_accounts': 0.0726472657331076,
#  'calculated_emi': 0.22266235306347604}

# %%
dict(sorted(dict(zip(model.feature_names_in_, model.feature_importances_)).items(), key=lambda item: item[1]))
# Out:
# {'p_equifax_income_35-40k': 0.000840759636746339,
#  'p_equifax_income_<10k': 0.0012291926403441415,
#  'p_equifax_income_30-35k': 0.0014166076722087,
#  'p_equifax_income_25-30k': 0.0015594624367703388,
#  'p_occupation_Salaried': 0.002229423003221367,
#  'p_occupation_Other': 0.0023750912763810792,
#  'p_equifax_income_20-25k': 0.0023870526078959577,
#  'p_occupation_SelfEmployed': 0.0025630058925737477,
#  'max_dpd': 0.0027478963305768507,
#  'p_equifax_income_10-15k': 0.0029928562548913067,
#  'p_customer_type_Green': 0.0030259107448792244,
#  'p_equifax_income_15-20k': 0.0034230344106855313,
#  'p_equifax_income_Other': 0.003893107639403112,
#  'p_customer_type_Red': 0.004377650354110502,
#  'p_customer_type_Amber': 0.00541366791592326,
#  'negative_status_accounts': 0.0066731215192579385,
#  'p_equifax_income_40-45k': 0.010635743615131558,
#  'no_of_delayed_payments': 0.012209415639807883,
#  'enquiries_made': 0.013307158935951977,
#  'no_of_delayed_payments_on_active_accounts': 0.015023151075070186,
#  'is_saleable': 0.017889805533838135,
#  'credit_utilization_avg': 0.020948597946791953,
#  'credit_utilization': 0.022110794853119654,
#  'existing_foir': 0.02423574124922107,
#  'p_credit_score': 0.027743068822902797,
#  'related_accounts': 0.030482204277843997,
#  'seasoning': 0.031213337531113196,
#  'open_accounts': 0.032716922583362035,
#  'annual_income': 0.03447112103152875,
#  'closed_accounts': 0.03789551634865576,
#  'portfolio_mix_unsecured': 0.041069014000718634,
#  'total_accounts': 0.0499337574601356,
#  'minor_issues': 0.05501855713489532,
#  'ontime_payment_percentage': 0.05875959565819891,
#  'positive_status_accounts': 0.059051818393183506,
#  'portfolio_mix_secured': 0.06282721877607603,
#  'no_of_active_accounts': 0.0726472657331076,
#  'calculated_emi': 0.22266235306347604}

# %%
joblib.dump(grid,"CH_AL_RF_v1.pkl")
# Out:
# ['CH_AL_RF_v1.pkl']

# %%
joblib.dump(model,"CH_AL_RF_v1.1.pkl")
# Out:
# ['CH_AL_RF_v1.1.pkl']

# %%
grid.best_estimator_
# Out:
# RandomForestClassifier(min_samples_leaf=2e-07, min_samples_split=2e-08,
#                        random_state=12)

# %%
test_fit2 = grid.predict(test_X)
y_pred=pd.DataFrame(test_fit2)

# %%
test_fit1 = model.predict(test_X)
y_pred1=pd.DataFrame(test_fit1)

# %%
test_fit3 = model.predict(train_X)
y_pred3=pd.DataFrame(test_fit3)

# %%
accuracy_score(test_y, y_pred)
# Out:
# 0.7426294820717132

# %%
accuracy_score(test_y, y_pred1)
# Out:
# 0.7426294820717132

# %%
accuracy_score(train_y, y_pred3)
# Out:
# 0.7956055639230973

# %%
cm=ConfusionMatrixDisplay(confusion_matrix(test_y, y_pred))
cm.plot()
plt.show()

# %%
cm=ConfusionMatrixDisplay(confusion_matrix(test_y, y_pred1))
cm.plot()
plt.show()

# %%
cm=ConfusionMatrixDisplay(confusion_matrix(train_y, y_pred3))
cm.plot()
plt.show()

# %%
false_positive_rate, true_positive_rate, threshold1 = roc_curve(test_y, y_pred)
'roc='+str(roc_auc_score(test_y, y_pred))
# Out:
# 'roc=0.7386479644448111'

# %%
false_positive_rate2, true_positive_rate2, threshold2 = roc_curve(test_y, y_pred1)
'roc='+str(roc_auc_score(test_y, y_pred1))
# Out:
# 'roc=0.7360841857779244'

# %%
false_positive_rate3, true_positive_rate3, threshold3 = roc_curve(train_y, y_pred3)
'roc='+str(roc_auc_score(train_y, y_pred3))
# Out:
# 'roc=0.7896695786850895'

# %%
mae = mean_absolute_error(test_y, y_pred)
mse = mean_squared_error(test_y, y_pred)
rmse = np.sqrt(mse) # or mse**(0.5)  
r2 = r2_score(test_y, y_pred)

print("Results of sklearn.metrics:")
print("MAE:",mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R-Squared:", r2)
# Out:
# Results of sklearn.metrics:
# MAE: 0.25737051792828686
# MSE: 0.25737051792828686
# RMSE: 0.5073169797358322
# R-Squared: -0.04501371473354232

# %%
mae = mean_absolute_error(test_y, y_pred1)
mse = mean_squared_error(test_y, y_pred1)
rmse = np.sqrt(mse) # or mse**(0.5)  
r2 = r2_score(test_y, y_pred1)

print("Results of sklearn.metrics:")
print("MAE:",mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R-Squared:", r2)
# Out:
# Results of sklearn.metrics:
# MAE: 0.25737051792828686
# MSE: 0.25737051792828686
# RMSE: 0.5073169797358322
# R-Squared: -0.04501371473354232

# %%
mae = mean_absolute_error(train_y, y_pred3)
mse = mean_squared_error(train_y, y_pred3)
rmse = np.sqrt(mse) # or mse**(0.5)  
r2 = r2_score(train_y, y_pred3)

print("Results of sklearn.metrics:")
print("MAE:",mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R-Squared:", r2)
# Out:
# Results of sklearn.metrics:
# MAE: 0.20439443607690264
# MSE: 0.20439443607690264
# RMSE: 0.4521000288397498
# R-Squared: 0.17134485657410758

# %%
plt.subplots(1, figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate, true_positive_rate)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
plt.subplots(1, figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate2, true_positive_rate2)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate 2')
plt.xlabel('False Positive Rate 2')
plt.show()

# %%
plt.subplots(1, figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate3, true_positive_rate3)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate 3')
plt.xlabel('False Positive Rate 3')
plt.show()

# %%
from pyfiglet import Figlet
import datetime
custom_fig = Figlet(font='starwars', width=130)
print(custom_fig.renderText('>>>     Training  Completed      <<<'))
custom_fig = Figlet(font='digital', width=120, justify='center')
print(custom_fig.renderText(str(datetime.datetime.now())))
# Out:
# ___  ___  ___                  .___________..______          ___       __  .__   __.  __  .__   __.   _______
# \  \ \  \ \  \                 |           ||   _  \        /   \     |  | |  \ |  | |  | |  \ |  |  /  _____|
#  \  \ \  \ \  \                `---|  |----`|  |_)  |      /  ^  \    |  | |   \|  | |  | |   \|  | |  |  __
#   >  > >  > >  >                   |  |     |      /      /  /_\  \   |  | |  . `  | |  | |  . `  | |  | |_ |
#  /  / /  / /  /                    |  |     |  |\  \----./  _____  \  |  | |  |\   | |  | |  |\   | |  |__| |
# /__/ /__/ /__/                     |__|     | _| `._____/__/     \__\ |__| |__| \__| |__| |__| \__|  \______|
#
#   ______   ______   .___  ___. .______    __       _______ .___________. _______  _______                       ___  ___  ___
#  /      | /  __  \  |   \/   | |   _  \  |  |     |   ____||           ||   ____||       \                     /  / /  / /  /
# |  ,----'|  |  |  | |  \  /  | |  |_)  | |  |     |  |__   `---|  |----`|  |__   |  .--.  |                   /  / /  / /  /
# |  |     |  |  |  | |  |\/|  | |   ___/  |  |     |   __|      |  |     |   __|  |  |  |  |                  <  < <  < <  <
# |  `----.|  `--'  | |  |  |  | |  |      |  `----.|  |____     |  |     |  |____ |  '--'  |                   \  \ \  \ \  \
#  \______| \______/  |__|  |__| | _|      |_______||_______|    |__|     |_______||_______/                     \__\ \__\ \__\
#
#
#                                  +-+-+-+-+-+-+-+-+-+-+ +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+
#                                  |2|0|2|3|-|0|3|-|3|1| |1|3|:|1|9|:|5|5|.|9|5|1|6|1|5|
#                                  +-+-+-+-+-+-+-+-+-+-+ +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+
